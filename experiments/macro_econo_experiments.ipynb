# %%
import pandas as pd
import numpy as np

macro_econo_file= "../data/MacrodataFiles11Oct2022/macro_features.pkl"
macro_econo_df = pd.read_pickle(macro_econo_file)

# %%
macro_econo_df["SGE/ESPMP - Value"]
# Out:
# {Timestamp('2009-01-31 00:00:00'): -22.8,
#  Timestamp('2009-02-28 00:00:00'): -22.4,
#  Timestamp('2009-03-31 00:00:00'): -22.9,
#  Timestamp('2009-04-30 00:00:00'): -22.1,
#  Timestamp('2009-05-31 00:00:00'): -21.0,
#  Timestamp('2009-06-30 00:00:00'): -18.1,
#  Timestamp('2009-07-31 00:00:00'): -17.8,
#  Timestamp('2009-08-31 00:00:00'): -15.6,
#  Timestamp('2009-09-30 00:00:00'): -14.6,
#  Timestamp('2009-10-31 00:00:00'): -7.6,
#  Timestamp('2009-11-30 00:00:00'): -6.0,
#  Timestamp('2009-12-31 00:00:00'): -1.0,
#  Timestamp('2010-01-31 00:00:00'): -1.1,
#  Timestamp('2010-02-28 00:00:00'): -1.4,
#  Timestamp('2010-03-31 00:00:00'): 2.5,
#  Timestamp('2010-04-30 00:00:00'): 3.0,
#  Timestamp('2010-05-31 00:00:00'): 3.0,
#  Timestamp('2010-06-30 00:00:00'): 2.4,
#  Timestamp('2010-07-31 00:00:00'): 0.4,
#  Timestamp('2010-08-31 00:00:00'): -0.8,
#  Timestamp('2010-09-30 00:00:00'): -1.6,
#  Timestamp('2010-10-31 00:00:00'): -0.7,
#  Timestamp('2010-11-30 00:00:00'): 1.2,
#  Timestamp('2010-12-31 00:00:00'): 0.6,
#  Timestamp('2011-01-31 00:00:00'): 1.6,
#  Timestamp('2011-02-28 00:00:00'): 2.9,
#  Timestamp('2011-03-31 00:00:00'): 0.4,
#  Timestamp('2011-04-30 00:00:00'): -0.8,
#  Timestamp('2011-05-31 00:00:00'): -1.5,
#  Timestamp('2011-06-30 00:00:00'): -1.6,
#  Timestamp('2011-07-31 00:00:00'): -0.4,
#  Timestamp('2011-08-31 00:00:00'): -0.6,
#  Timestamp('2011-09-30 00:00:00'): -1.5,
#  Timestamp('2011-10-31 00:00:00'): -3.3,
#  Timestamp('2011-11-30 00:00:00'): -5.1,
#  Timestamp('2011-12-31 00:00:00'): -3.3,
#  Timestamp('2012-01-31 00:00:00'): -4.9,
#  Timestamp('2012-02-29 00:00:00'): -8.1,
#  Timestamp('2012-03-31 00:00:00'): -8.5,
#  Timestamp('2012-04-30 00:00:00'): -9.2,
#  Timestamp('2012-05-31 00:00:00'): -7.4,
#  Timestamp('2012-06-30 00:00:00'): -7.4,
#  Timestamp('2012-07-31 00:00:00'): -8.1,
#  Timestamp('2012-08-31 00:00:00'): -6.7,
#  Timestamp('2012-09-30 00:00:00'): -7.9,
#  Timestamp('2012-10-31 00:00:00'): -6.6,
#  Timestamp('2012-11-30 00:00:00'): -8.4,
#  Timestamp('2012-12-31 00:00:00'): -8.8,
#  Timestamp('2013-01-31 00:00:00'): -6.2,
#  Timestamp('2013-02-28 00:00:00'): -4.3,
#  Timestamp('2013-03-31 00:00:00'): -2.7,
#  Timestamp('2013-04-30 00:00:00'): -2.1,
#  Timestamp('2013-05-31 00:00:00'): -2.2,
#  Timestamp('2013-06-30 00:00:00'): -1.7,
#  Timestamp('2013-07-31 00:00:00'): -1.4,
#  Timestamp('2013-08-31 00:00:00'): -1.6,
#  Timestamp('2013-09-30 00:00:00'): 0.7,
#  Timestamp('2013-10-31 00:00:00'): 0.1,
#  Timestamp('2013-11-30 00:00:00'): 2.8,
#  Timestamp('2013-12-31 00:00:00'): 2.8,
#  Timestamp('2014-01-31 00:00:00'): 2.7,
#  Timestamp('2014-02-28 00:00:00'): 3.2,
#  Timestamp('2014-03-31 00:00:00'): 2.6,
#  Timestamp('2014-04-30 00:00:00'): 3.5,
#  Timestamp('2014-05-31 00:00:00'): 2.4,
#  Timestamp('2014-06-30 00:00:00'): 1.2,
#  Timestamp('2014-07-31 00:00:00'): 1.5,
#  Timestamp('2014-08-31 00:00:00'): 1.0,
#  Timestamp('2014-09-30 00:00:00'): 1.3,
#  Timestamp('2014-10-31 00:00:00'): 1.8,
#  Timestamp('2014-11-30 00:00:00'): 1.0,
#  Timestamp('2014-12-31 00:00:00'): 1.1,
#  Timestamp('2015-01-31 00:00:00'): 0.0,
#  Timestamp('2015-02-28 00:00:00'): 1.2,
#  Timestamp('2015-03-31 00:00:00'): 2.3,
#  Timestamp('2015-04-30 00:00:00'): 2.8,
#  Timestamp('2015-05-31 00:00:00'): 4.1,
#  Timestamp('2015-06-30 00:00:00'): 4.8,
#  Timestamp('2015-07-31 00:00:00'): 5.3,
#  Timestamp('2015-08-31 00:00:00'): 4.4,
#  Timestamp('2015-09-30 00:00:00'): 5.8,
#  Timestamp('2015-10-31 00:00:00'): 5.7,
#  Timestamp('2015-11-30 00:00:00'): 6.2,
#  Timestamp('2015-12-31 00:00:00'): 6.1,
#  Timestamp('2016-01-31 00:00:00'): 6.9,
#  Timestamp('2016-02-29 00:00:00'): 5.2,
#  Timestamp('2016-03-31 00:00:00'): 4.1,
#  Timestamp('2016-04-30 00:00:00'): 4.0,
#  Timestamp('2016-05-31 00:00:00'): 1.3,
#  Timestamp('2016-06-30 00:00:00'): 2.0,
#  Timestamp('2016-07-31 00:00:00'): 1.1,
#  Timestamp('2016-08-31 00:00:00'): 3.0,
#  Timestamp('2016-09-30 00:00:00'): 0.6,
#  Timestamp('2016-10-31 00:00:00'): 0.5,
#  Timestamp('2016-11-30 00:00:00'): 1.5,
#  Timestamp('2016-12-31 00:00:00'): 1.6,
#  Timestamp('2017-01-31 00:00:00'): 1.4,
#  Timestamp('2017-02-28 00:00:00'): 1.6,
#  Timestamp('2017-03-31 00:00:00'): 2.5,
#  Timestamp('2017-04-30 00:00:00'): 1.4,
#  Timestamp('2017-05-31 00:00:00'): 4.4,
#  Timestamp('2017-06-30 00:00:00'): 2.9,
#  Timestamp('2017-07-31 00:00:00'): 3.9,
#  Timestamp('2017-08-31 00:00:00'): 3.2,
#  Timestamp('2017-09-30 00:00:00'): 4.7,
#  Timestamp('2017-10-31 00:00:00'): 5.3,
#  Timestamp('2017-11-30 00:00:00'): 4.8,
#  Timestamp('2017-12-31 00:00:00'): 5.1,
#  Timestamp('2018-01-31 00:00:00'): 2.9,
#  Timestamp('2018-02-28 00:00:00'): 2.5,
#  Timestamp('2018-03-31 00:00:00'): 2.4,
#  Timestamp('2018-04-30 00:00:00'): 2.1,
#  Timestamp('2018-05-31 00:00:00'): 1.8,
#  Timestamp('2018-06-30 00:00:00'): 2.2,
#  Timestamp('2018-07-31 00:00:00'): 1.9,
#  Timestamp('2018-08-31 00:00:00'): 1.4,
#  Timestamp('2018-09-30 00:00:00'): 0.3,
#  Timestamp('2018-10-31 00:00:00'): 0.1,
#  Timestamp('2018-11-30 00:00:00'): -1.9,
#  Timestamp('2018-12-31 00:00:00'): -2.4,
#  Timestamp('2019-01-31 00:00:00'): 0.7,
#  Timestamp('2019-02-28 00:00:00'): 1.2,
#  Timestamp('2019-03-31 00:00:00'): 0.6,
#  Timestamp('2019-04-30 00:00:00'): 1.7,
#  Timestamp('2019-05-31 00:00:00'): 1.2,
#  Timestamp('2019-06-30 00:00:00'): 1.4,
#  Timestamp('2019-07-31 00:00:00'): 0.8,
#  Timestamp('2019-08-31 00:00:00'): 0.7,
#  Timestamp('2019-09-30 00:00:00'): 0.1,
#  Timestamp('2019-10-31 00:00:00'): -0.7,
#  Timestamp('2019-11-30 00:00:00'): 0.7,
#  Timestamp('2019-12-31 00:00:00'): 0.1,
#  Timestamp('2020-01-31 00:00:00'): -1.5,
#  Timestamp('2020-02-29 00:00:00'): -2.1,
#  Timestamp('2020-03-31 00:00:00'): -17.0,
#  Timestamp('2020-04-30 00:00:00'): -38.0,
#  Timestamp('2020-05-31 00:00:00'): -26.6,
#  Timestamp('2020-06-30 00:00:00'): -14.9,
#  Timestamp('2020-07-31 00:00:00'): -6.5,
#  Timestamp('2020-08-31 00:00:00'): -5.8,
#  Timestamp('2020-09-30 00:00:00'): -3.5,
#  Timestamp('2020-10-31 00:00:00'): -2.0,
#  Timestamp('2020-11-30 00:00:00'): -2.2}

# %% [markdown]
# Reading the pickle file I can get a dictionary of dictionaries.
#
# Use the reference from `../data/MacrodataFiles11Oct2022/SGE_TradingEconomics_Metadata.csv` to investigate usage.
#
# Key is composed of `SGE/dataset_code - Value`
