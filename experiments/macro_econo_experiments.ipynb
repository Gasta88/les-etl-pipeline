# %% [markdown]
# # QUANDL
#
# Reading the pickle file I can get a dictionary of dictionaries.
#
# Use the reference from `../data/MacrodataFiles11Oct2022/SGE_TradingEconomics_Metadata.csv` to investigate usage.
#
# Key is composed of `SGE/dataset_code - Value`

# %%
import pandas as pd
import numpy as np
import unicodedata
from collections import OrderedDict

macro_econo_file= "../data/MacrodataFiles11Oct2022/quandl_datasets.pkl"
macro_econo_df = pd.read_pickle(macro_econo_file)

# %%
manifest_df = pd.read_csv("../data/MacrodataFiles11Oct2022/SGE_TradingEconomics_Metadata.csv")
nice_names = {}
char_to_replace = {'-': '_',
                   ' ': '_',
                   '(':'',
                   ')':'',}
# for i, r in manifest_df[["code","name"]].T.to_dict("list").items():
for i, r in manifest_df.T.to_dict("list").items():
    if r[0] in ["ALBRATING", "DZARATING"]:
        continue
    tmp_dataset_name = unicodedata.normalize("NFKD",r[1]).lower().replace(" - ", "-").replace(" -","").translate(str.maketrans(char_to_replace))
    clean_dataset_name = f"quandl_{tmp_dataset_name}"
    nice_names[r[0]] = [clean_dataset_name] + r[2:]

nice_names
# Out:
# {'ANDCUR': ['quandl_andorra',
#   'National currency of COUNTRYUnits: LCU ',
#   nan,
#   nan,
#   nan],
#  'ASMCUR': ['quandl_american_samoa',
#   'National currency of COUNTRYUnits: LCU ',
#   nan,
#   nan,
#   nan],
#  'EURSNTX': ['quandl_euro_area_sentix_investors_sentiment',
#   'This index published by Sentix tracks investor confidence in the Eurozone.Units:  Source: Sentix',
#   nan,
#   nan,
#   nan],
#  'MACDINV': ['quandl_macau_changes_in_inventories',
#   'The quarterly change in inventory levels in Macau.Units: MOP THO Constant Prices, NSASource: Statistics and Census Service, Government of Macao SAR',
#   nan,
#   nan,
#   nan],
#  'MACEMP': ['quandl_macau_employed_persons',
#   'The total number of employed (including self-employed) persons in Macau.Units: Thousand Volume, NSASource: Statistics and Census Service, Government of Macao SAR',
#   nan,
#   nan,
#   nan],
#  'MACGBVL': ['quandl_macau_government_budget_value',
#   'The balance of the federal budget of Macau. It consists of tax revenues and expenses on government services. Negative budget values denote budget deficits; positive budget values denote budget surpluses.Units: MOP Million Current Prices, NSASource: Monetary Authority Of Macao',
#   nan,
#   nan,
#   nan],
#  'MACGCP': ['quandl_macau_gdp_constant_prices',
#   'An inflation-adjusted measure of GDP in the Macau.Units: MOP THO Constant Prices, NSASource: Statistics and Census Service, Government of Macao SAR',
#   nan,
#   nan,
#   nan],
#  'MACGFCF': ['quandl_macau_gross_fixed_capital_formation',
#   'The net value of fixed capital flowing into businesses in Macau where fixed capital is the value of new fixed capital purchased by businesses less old fixed capital sold or disposed of, ignoring depreciation costs of existing fixed assets.Units: MOP THO Current Prices, NSASource: Statistics and Census Service Government of Macao SAR',
#   nan,
#   nan,
#   nan],
#  'MACGSP': ['quandl_macau_government_spending',
#   'The yearly expenditure of the federal government of Macau.Units: MOP THO Constant Prices, NSASource: Statistics and Census Service, Government of Macao SAR',
#   nan,
#   nan,
#   nan],
#  'MACIP': ['quandl_macau_industrial_production',
#   'The year-over-year percent change in the monthly industrial production of Macau.Units: Percent Source: Statistics and Census Service, Government of Macao SAR',
#   nan,
#   nan,
#   nan],
#  'MACM1': ['quandl_macau_money_supply_m1',
#   "M0 + the money in transactional bank accounts like checking accounts demand deposits, and travelers' checks.Units: MOP Million Current Prices, NSASource: Monetary Authority of Macao",
#   nan,
#   nan,
#   nan],
#  'MACM2': ['quandl_macau_money_supply_m2',
#   'M1 + savings deposits, small-denomination savings deposits, and retail money market mutual funds.Units: MOP Million Current Prices, NSASource: Monetary Authority of Macao',
#   nan,
#   nan,
#   nan],
#  'MACPOP': ['quandl_macau_population',
#   'The number of residents of Macau.Units: Million Source: Statistics and Census Service Government of Macao SAR',
#   nan,
#   nan,
#   nan],
#  'MACRSM': ['quandl_macau_retail_sales_mom',
#   'The monthly percent change in total retail sales in Macau.Units: Percent Source: Statistics and Census Service, Government of Macao SAR',
#   nan,
#   nan,
#   nan],
#  'MACRSY': ['quandl_macau_retail_sales_yoy',
#   'The per cent change in total monthly retail sales relative to one year earlier in Macau.Units: Percent Source: Statistics and Census Service, Government of Macao SAR',
#   nan,
#   nan,
#   nan],
#  'MACUNP': ['quandl_macau_unemployed_persons',
#   'The total members of the labor force of Macau who are unemployed and actively seeking work.Units: Thousand Volume, NSASource: Statistics and Census Service Government of Macao SAR',
#   nan,
#   nan,
#   nan],
#  'USANFPP': ['quandl_united_states_nonfarm_payrolls_private',
#   'The percent change in monthly retail sales.Units: Thousand Source: U.S. Bureau of Labor Statistics',
#   nan,
#   nan,
#   nan],
#  'ESPIR': ['quandl_spain_interest_rate',
#   'The daily average of the central bank policy rate in Spain. This is the interest rate the central bank charges on loans to commercial banks.Units: percent Source: European Central Bank',
#   '2019-01-28 11:53:24 UTC',
#   '1998-12-18',
#   '2019-01-24'],
#  'EURIR': ['quandl_euro_area_interest_rate',
#   'The daily average of the central bank policy rate in Euro area. This is the interest rate the central bank charges on loans to commercial banks.Units: percent Source: European Central Bank',
#   '2019-02-06 08:10:31 UTC',
#   '1998-12-18',
#   '2019-01-24'],
#  'SVNIR': ['quandl_slovenia_interest_rate',
#   'The daily average of the central bank policy rate in Slovenia. This is the interest rate the central bank charges on loans to commercial banks.Units: percent Source: European Central Bank',
#   '2019-01-28 11:53:24 UTC',
#   '1998-12-18',
#   '2019-01-24'],
#  'KORIR': ['quandl_south_korea_interest_rate',
#   'The daily average of the central bank policy rate in South Korea. This is the interest rate the central bank charges on loans to commercial banks.Units: percent Source: The Bank of Korea',
#   '2019-01-24 01:10:23 UTC',
#   '1999-05-06',
#   '2019-01-24'],
#  'MYSIR': ['quandl_malaysia_interest_rate',
#   'The daily average of the central bank policy rate in Malaysia. This is the interest rate the central bank charges on loans to commercial banks.Units: percent Source: Central Bank of Malaysia',
#   '2019-01-24 07:11:37 UTC',
#   '2004-04-26',
#   '2019-01-24'],
#  'MWIIP': ['quandl_malawi_industrial_production',
#   'The year-over-year percent change in the monthly industrial production of Malawi.Units: percent Source: National Statistical Office of Malawi',
#   '2019-02-12 09:37:04 UTC',
#   '2008-01-31',
#   '2017-08-31'],
#  'USACJC': ['quandl_united_states_continuing_jobless_claims',
#   'The number of people in the United States receiving unemployment benefits who also received benefits at least two weeks ago.Units: Thousand Volume, SASource: U.S. Department of Labor',
#   '2019-02-07 13:40:17 UTC',
#   '1967-01-07',
#   '2019-01-26'],
#  'KENIR': ['quandl_kenya_interest_rate',
#   'The daily average of the central bank policy rate in Kenya. This is the interest rate the central bank charges on loans to commercial banks.Units: percent Source: Central Bank of Kenya',
#   '2019-01-28 14:34:14 UTC',
#   '1991-07-31',
#   '2019-01-28'],
#  'GHAIR': ['quandl_ghana_interest_rate',
#   'The daily average of the central bank policy rate in Ghana. This is the interest rate the central bank charges on loans to commercial banks.Units: percent Source: Bank of Ghana',
#   '2019-01-29 12:18:01 UTC',
#   '2002-11-22',
#   '2019-01-28'],
#  'ARMIR': ['quandl_armenia_interest_rate',
#   'The daily average of the central bank policy rate in Armenia. This is the interest rate the central bank charges on loans to commercial banks.Units: percent Source: Central Bank of Armenia',
#   '2019-01-30 11:16:25 UTC',
#   '2010-10-12',
#   '2019-01-29'],
#  'HUNIR': ['quandl_hungary_interest_rate',
#   'The daily average of the central bank policy rate in Hungary. This is the interest rate the central bank charges on loans to commercial banks.Units: percent Source: National Bank of Hungary',
#   '2019-01-29 13:22:20 UTC',
#   '1987-01-01',
#   '2019-01-29'],
#  'FJIIR': ['quandl_fiji_interest_rate',
#   'The daily average of the central bank policy rate in Fiji. This is the interest rate the central bank charges on loans to commercial banks.Units: percent Source: Reserve Bank of Fiji',
#   '2019-01-29 12:18:00 UTC',
#   '2010-12-31',
#   '2019-01-29'],
#  'CHLIR': ['quandl_chile_interest_rate',
#   'The daily average of the central bank policy rate in Chile. This is the interest rate the central bank charges on loans to commercial banks.Units: percent Source: Banco Central de Chile',
#   '2019-01-30 21:10:51 UTC',
#   '1995-05-29',
#   '2019-01-30'],
#  'USAIR': ['quandl_united_states_fed_funds_rate',
#   'The monthly average of the central bank policy rate in the United States, commonly referred to as the Fed Funds Target Rate. This is the interest rate the central bank targets for loans to commercial banks. In the US, the rate is set by the FOMC.Units: percent Source: Federal Reserve',
#   '2019-02-12 17:57:16 UTC',
#   '1971-08-04',
#   '2019-01-30'],
#  'GEOIR': ['quandl_georgia_interest_rate',
#   'The daily average of the central bank policy rate in Georgia. This is the interest rate the central bank charges on loans to commercial banks.Units: percent Source: National Bank of Georgia',
#   '2019-01-31 11:41:10 UTC',
#   '2008-01-23',
#   '2019-01-30'],
#  'MWIIR': ['quandl_malawi_interest_rate',
#   'The daily average of the central bank policy rate in Malawi. This is the interest rate the central bank charges on loans to commercial banks.Units: percent Source: Reserve Bank of Malawi',
#   '2019-01-30 14:10:58 UTC',
#   '2001-01-31',
#   '2019-01-30'],
#  'AUSCBBS': ['quandl_australia_central_bank_balance_sheet',
#   'The value of assets less liabilities held by the central bank of Australia.Units: AUD Million Source: Reserve Bank of Australia',
#   '2019-02-08 11:14:13 UTC',
#   '1994-06-01',
#   '2019-01-30'],
#  'POLBCONF': ['quandl_poland_business_confidence',
#   'This monthly index tracks the outlook of representative firms on the future business climate of Poland. Units: Index Points Source: Central Statistical Office of Poland (GUS)',
#   '2019-01-28 11:53:20 UTC',
#   '1993-10-31',
#   '2019-01-31'],
#  'AUSCONPMI': ['quandl_australia_construction_pmi',
#   'Units: Index Points SASource: Australian Industry Group',
#   '2019-02-06 22:42:31 UTC',
#   '2005-09-30',
#   '2019-01-31'],
#  'VNMRSY': ['quandl_vietnam_retail_sales_yoy',
#   'The per cent change in total monthly retail sales relative to one year earlier in Vietnam.Units: percent Source: General Statistics Office of Vietnam',
#   '2019-01-29 12:18:18 UTC',
#   '2002-03-31',
#   '2019-01-31'],
#  'CHLCPIC': ['quandl_chile_inflation_rate',
#   'The growth rate of the prices in Chile.Units: percent 2013=100Source: National Institute of Statistics, Chile',
#   '2019-02-08 11:10:27 UTC',
#   '1951-01-31',
#   '2019-01-31'],
#  'CYPCPIC': ['quandl_cyprus_inflation_rate',
#   'The growth rate of the prices in Cyprus.Units: percent Source: Statistical Service of the Republic of Cyprus',
#   '2019-02-08 11:14:16 UTC',
#   '1951-01-31',
#   '2019-01-31'],
#  'GTMCPIC': ['quandl_guatemala_inflation_rate',
#   'The growth rate of the prices in Guatemala.Units: percent Dec 2010=100Source: Banco de Guatemala',
#   '2019-02-12 09:36:58 UTC',
#   '1951-01-31',
#   '2019-01-31'],
#  'MEXIBOR': ['quandl_mexico_28_days_interbank_rate',
#   'The monthly average of the twenty-eight day interbank rate in Mexico. This is the interest rate charged by banks lending money to other banks for repayment within twenty-eight days.Units: percent Source: Banco de Mexico',
#   '2019-02-08 11:14:23 UTC',
#   '1995-03-31',
#   '2019-01-31'],
#  'DEUSPMI': ['quandl_germany_services_pmi',
#   'This monthly index tracks the overall health of the services sector in Germany. Private sector reports on key quantitative indicators are amalgamated into an index whose value indicates expansion or contraction of the services sector. A PMI of 50% means equal numbers of respondents reported improvement and deterioration in the indicators from the previous month; PMIs above and below 50% indicate expansion and contraction of the sector respectively.Units: Index Points Source: Markit Economics',
#   '2019-02-05 09:05:12 UTC',
#   '2007-02-28',
#   '2019-01-31'],
#  'GBRSPMI': ['quandl_united_kingdom_services_pmi',
#   'This monthly index tracks the overall health of the services sector in the United Kingdom. Private sector reports on key quantitative indicators are amalgamated into an index whose value indicates expansion or contraction of the services sector. A PMI of 50% means equal numbers of respondents reported improvement and deterioration in the indicators from the previous month; PMIs above and below 50% indicate expansion and contraction of the sector respectively.Units: Index Points Source: Markit/CIPS',
#   '2019-02-05 09:40:20 UTC',
#   '2007-02-28',
#   '2019-01-31'],
#  'UGACPI': ['quandl_uganda_consumer_price_index_cpi',
#   'The Consumer Price Index (CPI) is a measure of inflation related to the cost of living. It tracks the prices of essential goods and services like food and healthcare, and weighs those price changes according to their relative importance. The overall change in prices is the inflation rate, which can be positive or negative. The standard CPI fails to account for price drops resulting from improved production technologies, so the chained CPI was crafted to allow for a continuously changing basket of goods.Units: Index Points 2009/2010=100, NSASource: Uganda Bureau of Statistics',
#   '2019-02-01 11:29:44 UTC',
#   '2010-08-31',
#   '2019-01-31'],
#  'KORBCONF': ['quandl_south_korea_business_confidence',
#   'This monthly index tracks the outlook of representative firms on the future business climate of South Korea. Units: Index Points NSASource: The Bank of Korea',
#   '2019-01-30 11:16:48 UTC',
#   '1991-09-30',
#   '2019-01-31'],
#  'FRABCONF': ['quandl_france_business_confidence',
#   'This monthly index tracks the outlook of representative firms on the future business climate of France. Units: Index Points SASource: INSEE, France',
#   '2019-01-23 07:55:16 UTC',
#   '1976-04-30',
#   '2019-01-31'],
#  'FRANO': ['quandl_france_new_orders_received',
#   'The market value of new orders of manufactured goods in France by month.Units: Index Points Seasonally AdjustedSource: INSEE, France',
#   '2019-02-01 11:29:34 UTC',
#   '1976-04-30',
#   '2019-01-31'],
#  'CANPTEMP': ['quandl_canada_part_time_employment_change',
#   'Units: Thousand SASource: CANSIM - Statistics Canada',
#   '2019-02-08 13:40:28 UTC',
#   '2015-07-31',
#   '2019-01-31'],
#  'DEUCONPMI': ['quandl_germany_construction_pmi',
#   'Units:  SASource: Markit Economics',
#   '2019-02-06 08:40:19 UTC',
#   '2015-07-31',
#   '2019-01-31'],
#  'GBRCONPMI': ['quandl_united_kingdom_construction_pmi',
#   'Units:  NSASource: Markit Economics',
#   '2019-02-04 09:40:09 UTC',
#   '2015-07-31',
#   '2019-01-31'],
#  'USAISMNYI': ['quandl_united_states_ism_new_york_index',
#   'Units: percent SASource: Institute for Supply Management',
#   '2019-02-04 14:55:16 UTC',
#   '2015-07-31',
#   '2019-01-31'],
#  'USANFPRPV': ['quandl_united_states_nonfarm_payrolls_private',
#   'Units: Thousand Source: U.S. Bureau of Labor Statistics',
#   '2019-02-01 13:40:41 UTC',
#   '2015-07-31',
#   '2019-01-31'],
#  'FRACNCN': ['quandl_france_consumer_confidence',
#   "This monthly index tracks consumers' opinions about their current economic well-being and outlook for the economy. It provides insight into consumers' short-term spending, saving, and borrowing plans.Units: Index Points SASource: INSEE, France",
#   '2019-01-29 07:55:14 UTC',
#   '1972-10-31',
#   '2019-01-31'],
#  'CHNSPMI': ['quandl_china_services_pmi',
#   'This monthly index tracks the overall health of the services sector in China. Private sector reports on key quantitative indicators are amalgamated into an index whose value indicates expansion or contraction of the services sector. A PMI of 50% means equal numbers of respondents reported improvement and deterioration in the indicators from the previous month; PMIs above and below 50% indicate expansion and contraction of the sector respectively.Units: Index Points Source: HSBC',
#   '2019-02-03 09:30:44 UTC',
#   '2012-01-31',
#   '2019-01-31'],
#  'INDCPIC': ['quandl_india_inflation_rate',
#   'The growth rate of the prices in India.Units: percent 2012=100Source: Ministry of Statistics and Programme Implementation (MOSPI), India',
#   '2019-02-12 12:10:33 UTC',
#   '2012-01-31',
#   '2019-01-31'],
#  'ITAMPMI': ['quandl_italy_manufacturing_pmi',
#   'This monthly index tracks the health of the manufacturing sector in Italy. Private sector companies report improvement or deterioration in key quantitative indicators like new orders, production, inventories, and employment levels. Responses are amalgamated into an index whose value indicates expansion or contraction of the manufacturing sector. A PMI of 50% means equal numbers of respondents reported improvement and deterioration and there is no change from the previous month; PMIs above and below 50% indicate expansion and contraction of the sector respectively.Units:  SASource: Markit/ADACI',
#   '2019-02-01 11:29:37 UTC',
#   '2012-01-31',
#   '2019-01-31'],
#  'PAKCNCN': ['quandl_pakistan_consumer_confidence',
#   "This monthly index tracks consumers' opinions about their current economic well-being and outlook for the economy. It provides insight into consumers' short-term spending, saving, and borrowing plans.Units: Index Points Source: State Bank of Pakistan",
#   '2019-02-01 11:29:39 UTC',
#   '2012-01-31',
#   '2019-01-31'],
#  'PAKCPI': ['quandl_pakistan_consumer_price_index_cpi',
#   'The Consumer Price Index (CPI) is a measure of inflation related to the cost of living. It tracks the prices of essential goods and services like food and healthcare, and weighs those price changes according to their relative importance. The overall change in prices is the inflation rate, which can be positive or negative. The standard CPI fails to account for price drops resulting from improved production technologies, so the chained CPI was crafted to allow for a continuously changing basket of goods.Units: Index Points 2007/2008=100, NSASource: Pakistan Bureau of Statistics',
#   '2019-02-08 11:14:24 UTC',
#   '2001-07-31',
#   '2019-01-31'],
#  'USAEMPST': ['quandl_united_states_ny_empire_state_manufacturing_index',
#   'This monthly index tracks the overall climate for manufacturing in New York State. It is based on regular surveys of approximately two hundred manufacturing industry executives who report data on key quantitative indicators like orders, shipments, inventories, employment levels, and capital expenditures.  The index also includes a subjective component reflecting the sentiment of the survey participants. Units: Index Points SASource: Federal Reserve Bank of New York',
#   '2019-01-18 10:48:41 UTC',
#   '2001-07-31',
#   '2019-01-31'],
#  'CHNBCONF': ['quandl_china_nbs_manufacturing_pmi',
#   'This monthly index tracks the outlook of representative firms on the future business climate of China. Units: Index Points Source: National Bureau of Statistics of China',
#   '2019-01-31 01:21:08 UTC',
#   '2005-01-31',
#   '2019-01-31'],
#  'CHNNO': ['quandl_china_new_orders',
#   'The market value of new orders of manufactured goods in China by month.Units: Index Points SASource: National Bureau of Statistics of China',
#   '2019-02-08 11:14:15 UTC',
#   '2005-01-31',
#   '2019-01-31'],
#  'DNKBCONF': ['quandl_denmark_business_confidence',
#   'This monthly index tracks the outlook of representative firms on the future business climate of Denmark. Units: Index Points SASource: Statistics Denmark',
#   '2019-01-30 07:10:47 UTC',
#   '2005-01-31',
#   '2019-01-31'],
#  'IDNCPICM': ['quandl_indonesia_inflation_rate_mom',
#   'The monthly percent change consumer prices of Indonesia.Units: percent NSASource: Statistics Indonesia',
#   '2019-02-01 11:29:36 UTC',
#   '2005-01-31',
#   '2019-01-31'],
#  'KENCPIC': ['quandl_kenya_inflation_rate',
#   'The growth rate of the prices in Kenya.Units: percent 2009M2=100, NSASource: Kenya National Bureau of Statistics',
#   '2019-01-31 11:10:40 UTC',
#   '2005-01-31',
#   '2019-01-31'],
#  'PRYCPIC': ['quandl_paraguay_inflation_rate',
#   'The growth rate of the prices in Paraguay.Units: percent 2007M12=100, NSASource: Banco Central del Paraguay',
#   '2019-02-01 17:40:38 UTC',
#   '2005-01-31',
#   '2019-01-31'],
#  'RUSBCONF': ['quandl_russia_business_confidence',
#   'This monthly index tracks the outlook of representative firms on the future business climate of Russia. Units: Index Points Source: Federal State Statistics Service',
#   '2019-02-04 13:20:05 UTC',
#   '2005-01-31',
#   '2019-01-31'],
#  'IRLCONPMI': ['quandl_ireland_ulster_bank_construction_pmi',
#   'Units:  SASource: Markit Economics',
#   '2019-02-11 01:11:19 UTC',
#   '2013-06-30',
#   '2019-01-31'],
#  'ISLCPICM': ['quandl_iceland_inflation_rate_mom',
#   'The monthly percent change consumer prices of Iceland.Units: percent Jan 2008=100Source: Statistics Iceland',
#   '2019-01-29 09:10:15 UTC',
#   '1979-02-28',
#   '2019-01-31'],
#  'CZECNCN': ['quandl_czech_republic_consumer_confidence',
#   "This monthly index tracks consumers' opinions about their current economic well-being and outlook for the economy. It provides insight into consumers' short-term spending, saving, and borrowing plans.Units: Index Points 2005=100, SASource: Czech Statistical Office",
#   '2019-01-24 08:10:25 UTC',
#   '1998-01-31',
#   '2019-01-31'],
#  'ECUPPI': ['quandl_ecuador_producer_prices',
#   'This index tracks the average prices domestic producers receive for their output in Ecuador. These are the prices of final goods as they leave the factory gate rather than the prices set by wholesalers and resellers.Units: Index Points 2015=100, NSASource: Banco Central Del Ecuador',
#   '2019-02-12 09:36:56 UTC',
#   '1998-01-31',
#   '2019-01-31'],
#  'IDNDIR': ['quandl_indonesia_deposit_facility_rate',
#   'Units: percent NSASource: Bank Indonesia',
#   '2019-01-18 10:48:33 UTC',
#   '1998-01-31',
#   '2019-01-31'],
#  'KAZCPI': ['quandl_kazakhstan_consumer_price_index_cpi',
#   'The Consumer Price Index (CPI) is a measure of inflation related to the cost of living. It tracks the prices of essential goods and services like food and healthcare, and weighs those price changes according to their relative importance. The overall change in prices is the inflation rate, which can be positive or negative. The standard CPI fails to account for price drops resulting from improved production technologies, so the chained CPI was crafted to allow for a continuously changing basket of goods.Units: Index Points PP=100, NSASource: Agency of Statistics of the Republic of Kazakhstan',
#   '2019-02-12 09:37:01 UTC',
#   '1998-01-31',
#   '2019-01-31'],
#  'KAZPPI': ['quandl_kazakhstan_producer_prices',
#   'This index tracks the average prices domestic producers receive for their output in Kazakhstan. These are the prices of final goods as they leave the factory gate rather than the prices set by wholesalers and resellers.Units: Index Points 1995=100, NSASource: The National Bank of Kazakhstan',
#   '2019-02-12 09:37:01 UTC',
#   '1998-01-31',
#   '2019-01-31'],
#  'LTUPPIC': ['quandl_lithuania_producer_prices_change_',
#   'The monthly percent change in the Producer Prices Index of Lithuania.Units: percent NSASource: Statistics Lithuania',
#   '2019-02-13 07:10:20 UTC',
#   '1998-01-31',
#   '2019-01-31'],
#  'LVACPIC': ['quandl_latvia_inflation_rate',
#   'The growth rate of the prices in Latvia.Units: percent 2015=100Source: Central Statistical Bureau of Latvia',
#   '2019-02-11 11:10:18 UTC',
#   '1998-01-31',
#   '2019-01-31'],
#  'ZAFFER': ['quandl_south_africa_foreign_exchange_reserves',
#   'The market value of the foreign currency reserves held by South Africa.Units: USD Million Current Prices, NSASource: South African Reserve Bank',
#   '2019-02-07 06:10:29 UTC',
#   '1998-01-31',
#   '2019-01-31'],
#  'UKRIR': ['quandl_ukraine_interest_rate',
#   'The daily average of the central bank policy rate in Ukraine. This is the interest rate the central bank charges on loans to commercial banks.Units: percent Source: National Bank of Ukraine',
#   '2019-01-31 12:10:49 UTC',
#   '1992-06-25',
#   '2019-01-31'],
#  'BLRCPI': ['quandl_belarus_consumer_price_index_cpi',
#   'The Consumer Price Index (CPI) is a measure of inflation related to the cost of living. It tracks the prices of essential goods and services like food and healthcare, and weighs those price changes according to their relative importance. The overall change in prices is the inflation rate, which can be positive or negative. The standard CPI fails to account for price drops resulting from improved production technologies, so the chained CPI was crafted to allow for a continuously changing basket of goods.Units: Index Points 1990M12=100, NSASource: National Statistical Committee of the Republic of Belarus',
#   '2019-02-12 09:36:50 UTC',
#   '1991-01-31',
#   '2019-01-31'],
#  'CHEBCONF': ['quandl_switzerland_business_confidence',
#   'This monthly index tracks the outlook of representative firms on the future business climate of Switzerland. Units: Index Points NSASource: Swiss Economic Institute (KOF)',
#   '2019-01-30 11:16:49 UTC',
#   '1991-01-31',
#   '2019-01-31'],
#  'CHLBOT': ['quandl_chile_balance_of_trade',
#   'The monthly net financial position of Chile in the global goods and services market, measured as the difference in value between its imports and exports. A negative trade balance indicates imports exceed exports; a positive trade balance indicates exports exceed imports.Units: USD Million Source: Banco Central de Chile',
#   '2019-02-07 11:40:19 UTC',
#   '1991-01-31',
#   '2019-01-31'],
#  'CHLEXVOL': ['quandl_chile_exports',
#   'The total value of the goods and services produced by Chile and purchased by foreign entities.Units: USD Million Source: Banco Central de Chile',
#   '2019-02-08 11:14:14 UTC',
#   '1991-01-31',
#   '2019-01-31'],
#  'CHLIMVOL': ['quandl_chile_imports',
#   "The total value of a country's imports of physical goods and payments to foreigners for services like shipping and tourism.Units: USD Million Source: Banco Central de Chile",
#   '2019-02-08 11:14:14 UTC',
#   '1991-01-31',
#   '2019-01-31'],
#  'CYPCARS': ['quandl_cyprus_motor_vehicle_registrations',
#   'The number of new car registrations per month in Cyprus.Units:  Volume, NSASource: Statistical Service of the Republic of Cyprus',
#   '2019-02-12 09:36:54 UTC',
#   '1991-01-31',
#   '2019-01-31'],
#  'DEUBCONF': ['quandl_germany_business_confidence',
#   'This monthly index tracks the outlook of representative firms on the future business climate of Germany. Units: Index Points 2015=100, SASource: IFO Institute',
#   '2019-01-25 09:10:57 UTC',
#   '1991-01-31',
#   '2019-01-31'],
#  'EURCPIC': ['quandl_euro_area_inflation_rate',
#   'The growth rate of the prices in Euro area.Units: percent Source: Eurostat',
#   '2019-02-01 11:29:34 UTC',
#   '1991-01-31',
#   '2019-01-31'],
#  'ISRTOUR': ['quandl_israel_tourist_arrivals',
#   'The number of tourists visiting Israel from foreign countries.Units: Thousand Source: Central Bureau of Statistics, Israel',
#   '2019-02-12 09:37:00 UTC',
#   '1991-01-31',
#   '2019-01-31'],
#  'ITABCONF': ['quandl_italy_business_confidence',
#   'This monthly index tracks the outlook of representative firms on the future business climate of Italy. Units: Index Points Source: ISAE/ISTAT',
#   '2019-01-30 09:10:37 UTC',
#   '1991-01-31',
#   '2019-01-31'],
#  'POLFER': ['quandl_poland_foreign_exchange_reserves',
#   'The market value of the foreign currency reserves held by Poland.Units: USD Million Current Prices, NSASource: National Bank of Poland',
#   '2019-02-07 13:21:29 UTC',
#   '1991-01-31',
#   '2019-01-31'],
#  'CHEFER': ['quandl_switzerland_foreign_exchange_reserves',
#   'The market value of the foreign currency reserves held by Switzerland.Units: CHF Million Current Prices, NSASource: Swiss National Bank',
#   '2019-02-07 08:10:36 UTC',
#   '1999-06-30',
#   '2019-01-31'],
#  'COLPPI': ['quandl_colombia_producer_prices',
#   'This index tracks the average prices domestic producers receive for their output in Colombia. These are the prices of final goods as they leave the factory gate rather than the prices set by wholesalers and resellers.Units: Index Points 2014 M12=100, NSASource: Dane, Colombia',
#   '2019-02-08 11:14:15 UTC',
#   '1999-06-30',
#   '2019-01-31'],
#  'KORUNR': ['quandl_south_korea_unemployment_rate',
#   'The percentage of the labor force of South Korea who are unemployed and actively seeking work.Units: percent SASource: Statistics Korea',
#   '2019-02-12 23:19:53 UTC',
#   '1999-06-30',
#   '2019-01-31'],
#  'BLRFER': ['quandl_belarus_foreign_exchange_reserves',
#   'The market value of the foreign currency reserves held by Belarus.Units: USD Million Current Prices, NSASource: National Bank of the Republic of Belarus',
#   '2019-02-12 09:36:50 UTC',
#   '2002-12-31',
#   '2019-01-31'],
#  'NORCCPI': ['quandl_norway_core_consumer_prices',
#   'This index tracks prices of consumer goods excluding food, energy and other items with high price volatility.Units: Index Points 2015=100, NSASource: Statistics Norway',
#   '2019-02-12 09:37:06 UTC',
#   '2002-12-31',
#   '2019-01-31'],
#  'ITASPMI': ['quandl_italy_services_pmi',
#   'This monthly index tracks the overall health of the services sector in Italy. Private sector reports on key quantitative indicators are amalgamated into an index whose value indicates expansion or contraction of the services sector. A PMI of 50% means equal numbers of respondents reported improvement and deterioration in the indicators from the previous month; PMIs above and below 50% indicate expansion and contraction of the sector respectively.Units: Index Points Source: Markit/ADACI',
#   '2019-02-05 08:55:21 UTC',
#   '2011-05-31',
#   '2019-01-31'],
#  'KORMPMI': ['quandl_south_korea_manufacturing_pmi',
#   'This monthly index tracks the health of the manufacturing sector in South Korea. Private sector companies report improvement or deterioration in key quantitative indicators like new orders, production, inventories, and employment levels. Responses are amalgamated into an index whose value indicates expansion or contraction of the manufacturing sector. A PMI of 50% means equal numbers of respondents reported improvement and deterioration and there is no change from the previous month; PMIs above and below 50% indicate expansion and contraction of the sector respectively.Source: HSBC',
#   '2019-02-01 00:43:39 UTC',
#   '2011-05-31',
#   '2019-01-31'],
#  'IRLIBOR': ['quandl_ireland_three_month_interbank_rate',
#   'The monthly average of the three-month interbank rate in Ireland. This is the interest rate charged by banks on loans to other banks for repayment within three months. Units: percent Source: Central Bank of Ireland',
#   '2019-02-08 11:14:21 UTC',
#   '1984-01-31',
#   '2019-01-31'],
#  'BGRFER': ['quandl_bulgaria_foreign_exchange_reserves',
#   'The market value of the foreign currency reserves held by Bulgaria.Units: BGN Million Current Prices, NSASource: Bulgarian National Bank',
#   '2019-02-12 09:36:52 UTC',
#   '1995-12-31',
#   '2019-01-31'],
#  'BLRUNR': ['quandl_belarus_unemployment_rate',
#   'The percentage of the labor force of Belarus who are unemployed and actively seeking work.Units: percent Source: National Statistical Committee of the Republic of Belarus',
#   '2019-01-23 09:43:40 UTC',
#   '1995-12-31',
#   '2019-01-31'],
#  'KORCPICM': ['quandl_south_korea_inflation_rate_mom',
#   'The monthly percent change consumer prices of South Korea.Units: percent 2015=100, NSASource: Statistics Korea',
#   '2019-01-31 23:12:57 UTC',
#   '1965-02-28',
#   '2019-01-31'],
#  'CANHSTT': ['quandl_canada_housing_starts',
#   'The number of houses whose construction started the previous month in Canada. Units: Thousand units Volume, SASource: Canada Mortgage And Housing Corporation',
#   '2019-02-08 13:25:23 UTC',
#   '1977-01-31',
#   '2019-01-31'],
#  'CRICPIC': ['quandl_costa_rica_inflation_rate',
#   'The growth rate of the prices in Costa Rica.Units: percent 2015=100Source: Instituto Nacional de Estadstica y Censos de Costa Rica',
#   '2019-02-07 16:25:20 UTC',
#   '1977-01-31',
#   '2019-01-31'],
#  'DNKFER': ['quandl_denmark_foreign_exchange_reserves',
#   'The market value of the foreign currency reserves held by Denmark.Units: DKK Million Current Prices, NSASource: Danmarks Nationalbank',
#   '2019-02-12 09:36:55 UTC',
#   '1977-01-31',
#   '2019-01-31'],
#  'LKATOUR': ['quandl_sri_lanka_tourist_arrivals',
#   'The number of tourists visiting Sri Lanka from foreign countries.Source: Ceylon Tourist Board',
#   '2019-02-12 09:37:11 UTC',
#   '1977-01-31',
#   '2019-01-31'],
#  'NORPPI': ['quandl_norway_producer_prices',
#   'This index tracks the average prices domestic producers receive for their output in Norway. These are the prices of final goods as they leave the factory gate rather than the prices set by wholesalers and resellers.Units: Index Points 2000=100, NSASource: Statistics Norway',
#   '2019-02-12 09:37:07 UTC',
#   '1977-01-31',
#   '2019-01-31'],
#  'THACPIC': ['quandl_thailand_inflation_rate',
#   'The growth rate of the prices in Thailand.Units: percent NSASource: Bureau of Trade and Economic Indices, Ministry of Commerce, Thailand',
#   '2019-02-01 11:29:43 UTC',
#   '1977-01-31',
#   '2019-01-31'],
#  'FRACPIC': ['quandl_france_inflation_rate',
#   'The growth rate of the prices in France.Units: percent 2015=100, NSASource: INSEE, France',
#   '2019-01-31 07:55:24 UTC',
#   '1958-02-28',
#   '2019-01-31'],
#  'EGYMPMI': ['quandl_egypt_non_oil_private_sector_pmi',
#   'This monthly index tracks the health of the manufacturing sector in Egypt. Private sector companies report improvement or deterioration in key quantitative indicators like new orders, production, inventories, and employment levels. Responses are amalgamated into an index whose value indicates expansion or contraction of the manufacturing sector. A PMI of 50% means equal numbers of respondents reported improvement and deterioration and there is no change from the previous month; PMIs above and below 50% indicate expansion and contraction of the sector respectively.Units:  SASource: HSBC',
#   '2019-02-05 04:25:23 UTC',
#   '2012-10-31',
#   '2019-01-31'],
#  'ECUCPIC': ['quandl_ecuador_inflation_rate',
#   'The growth rate of the prices in Ecuador.Units: percent 2014=100Source: INEC, Ecuador',
#   '2019-02-06 14:10:23 UTC',
#   '1970-01-31',
#   '2019-01-31'],
#  'JPNCARS': ['quandl_japan_car_registrations',
#   'The number of new car registrations per month in Japan.Units:  Volume, NSASource: Japan Automobile Dealers Association',
#   '2019-02-08 11:14:22 UTC',
#   '1970-01-31',
#   '2019-01-31'],
#  'PERCPIC': ['quandl_peru_inflation_rate',
#   'The growth rate of the prices in Peru.Units: percent 2001=100Source: Instituto Nacional de Estadstica e Informtica (INEI)',
#   '2019-02-02 09:52:21 UTC',
#   '1970-01-31',
#   '2019-01-31'],
#  'COLIR': ['quandl_colombia_interest_rate',
#   'The daily average of the central bank policy rate in Colombia. This is the interest rate the central bank charges on loans to commercial banks.Units: percent Source: Banco de la Repblica de Colombia',
#   '2019-02-12 09:36:46 UTC',
#   '1998-02-13',
#   '2019-01-31'],
#  'COLCPICM': ['quandl_colombia_inflation_rate_mom',
#   'The monthly percent change consumer prices of Colombia.Units: percent Source: Dane, Colombia',
#   '2019-02-06 09:49:56 UTC',
#   '1954-08-31',
#   '2019-01-31'],
#  'PERBCONF': ['quandl_peru_business_confidence',
#   'This monthly index tracks the outlook of representative firms on the future business climate of Peru. Units: Index Points Source: Central Reserve Bank of Peru',
#   '2019-02-12 09:37:07 UTC',
#   '2002-04-30',
#   '2019-01-31'],
#  'TUNCPIC': ['quandl_tunisia_inflation_rate',
#   'The growth rate of the prices in Tunisia.Units: percent 2005=100Source: National Institute of Statistics - Tunisia',
#   '2019-02-07 09:54:10 UTC',
#   '1963-01-31',
#   '2019-01-31'],
#  'THACNCN': ['quandl_thailand_consumer_confidence',
#   "This monthly index tracks consumers' opinions about their current economic well-being and outlook for the economy. It provides insight into consumers' short-term spending, saving, and borrowing plans.Units: Index Points Source: University of the Thai Chamber of Commerce",
#   '2019-02-06 09:50:14 UTC',
#   '1998-10-31',
#   '2019-01-31'],
#  'CHECPIC': ['quandl_switzerland_inflation_rate',
#   'The growth rate of the prices in Switzerland.Units: percent Source: Swiss Federal Statistical Office',
#   '2019-02-11 09:29:24 UTC',
#   '1956-01-31',
#   '2019-01-31'],
#  'ROUCPIC': ['quandl_romania_inflation_rate',
#   'The growth rate of the prices in Romania.Units: percent 1990=100Source: Institutul National de Statistica',
#   '2019-02-13 07:10:20 UTC',
#   '1991-10-31',
#   '2019-01-31'],
#  'ISLHOUS': ['quandl_iceland_house_price_index',
#   'This monthly index tracks residential house prices in Iceland. The index increases as housing becomes more expensive and decreases when it becomes cheaper.Units: Index Points 2003=100, NSASource: Statistics Iceland',
#   '2019-02-12 09:36:59 UTC',
#   '2000-03-31',
#   '2019-01-31'],
#  'NLDMPMI': ['quandl_netherlands_nevi_manufacturing_pmi',
#   'This monthly index tracks the health of the manufacturing sector in the Netherlands. Private sector companies report improvement or deterioration in key quantitative indicators like new orders, production, inventories, and employment levels. Responses are amalgamated into an index whose value indicates expansion or contraction of the manufacturing sector. A PMI of 50% means equal numbers of respondents reported improvement and deterioration and there is no change from the previous month; PMIs above and below 50% indicate expansion and contraction of the sector respectively.Source: Markit Economics',
#   '2019-02-01 11:29:38 UTC',
#   '2012-02-29',
#   '2019-01-31'],
#  'SGPMPMI': ['quandl_singapore_manufacturing_pmi',
#   'This monthly index tracks the health of the manufacturing sector in Singapore. Private sector companies report improvement or deterioration in key quantitative indicators like new orders, production, inventories, and employment levels. Responses are amalgamated into an index whose value indicates expansion or contraction of the manufacturing sector. A PMI of 50% means equal numbers of respondents reported improvement and deterioration and there is no change from the previous month; PMIs above and below 50% indicate expansion and contraction of the sector respectively.Source: Singapore Institute of Purchasing & Materials Management, SIPMM',
#   '2019-02-04 13:20:05 UTC',
#   '2012-02-29',
#   '2019-01-31'],
#  'CZEBCONF': ['quandl_czech_republic_business_confidence',
#   'This monthly index tracks the outlook of representative firms on the future business climate of the Czech Republic. Units: Index Points 2005=100, SASource: Czech Statistical Office',
#   '2019-01-24 08:10:25 UTC',
#   '1993-03-31',
#   '2019-01-31'],
#  'FRASPMI': ['quandl_france_services_pmi',
#   'This monthly index tracks the overall health of the services sector in France. Private sector reports on key quantitative indicators are amalgamated into an index whose value indicates expansion or contraction of the services sector. A PMI of 50% means equal numbers of respondents reported improvement and deterioration in the indicators from the previous month; PMIs above and below 50% indicate expansion and contraction of the sector respectively.Units: Index Points Source: Markit Economics',
#   '2019-02-05 09:00:19 UTC',
#   '2008-08-31',
#   '2019-01-31'],
#  'URYCPIC': ['quandl_uruguay_inflation_rate',
#   'The growth rate of the prices in Uruguay.Units: percent 2010=100Source: Instituto Nacional de Estadstica, Uruguay',
#   '2019-02-06 17:10:17 UTC',
#   '1938-07-31',
#   '2019-01-31'],
#  'AUSIBOR': ['quandl_australia_three_month_interbank_rate',
#   'The monthly average of the three-month interbank rate in Australia. This is the interest rate charged by banks on loans to other banks for repayment within three months. Units: percent Source: Reserve Bank of Australia',
#   '2019-02-08 11:14:13 UTC',
#   '1986-03-31',
#   '2019-01-31'],
#  'BRAMINWG': ['quandl_brazil_minimum_monthly_wages',
#   'The minimum wage in Brazil.Units: BRL/Month Current Prices, NSASource: The Institute for Applied Economic Research (IPEA)',
#   '2019-01-18 10:48:28 UTC',
#   '1994-08-31',
#   '2019-01-31'],
#  'ETHCPIC': ['quandl_ethiopia_inflation_rate',
#   'The growth rate of the prices in Ethiopia.Units: percent Source: Central Statistical Agency of Ethiopia',
#   '2019-02-05 12:10:17 UTC',
#   '2006-07-31',
#   '2019-01-31'],
#  'PAKCINF': ['quandl_pakistan_core_inflation_rate',
#   'The rate of change of the core Consumer Price Index of Pakistan.Units: percent Source: State Bank of Pakistan',
#   '2019-02-08 11:14:24 UTC',
#   '2010-01-31',
#   '2019-01-31'],
#  'AUSJOBADV': ['quandl_australia_job_advertisements',
#   'Units:  SASource: Australia and New Zealand Banking Group',
#   '2019-02-08 11:14:13 UTC',
#   '1999-07-31',
#   '2019-01-31'],
#  'MEXPPI': ['quandl_mexico_producer_prices',
#   'This index tracks the average prices domestic producers receive for their output in Mexico. These are the prices of final goods as they leave the factory gate rather than the prices set by wholesalers and resellers.Units: Index Points 2012M6=100, NSASource: Instituto Nacional de Estadstica y Geografa (INEGI)',
#   '2019-02-08 11:14:23 UTC',
#   '2003-01-31',
#   '2019-01-31'],
#  'RUSCINF': ['quandl_russia_core_inflation_rate',
#   'The rate of change of the core Consumer Price Index of Russia.Units: percent NSASource: Federal State Statistics Service',
#   '2019-02-08 11:14:26 UTC',
#   '2003-01-31',
#   '2019-01-31'],
#  'SVKGBVL': ['quandl_slovakia_government_budget_value',
#   'The balance of the federal budget of Slovakia. It consists of tax revenues and expenses on government services. Negative budget values denote budget deficits; positive budget values denote budget surpluses.Units: EUR Million Current Prices, NSASource: Ministry Of Finance Of Slovak Republic',
#   '2019-02-12 09:37:09 UTC',
#   '2003-01-31',
#   '2019-01-31'],
#  'TURCPI': ['quandl_turkey_consumer_price_index_cpi',
#   'The Consumer Price Index (CPI) is a measure of inflation related to the cost of living. It tracks the prices of essential goods and services like food and healthcare, and weighs those price changes according to their relative importance. The overall change in prices is the inflation rate, which can be positive or negative. The standard CPI fails to account for price drops resulting from improved production technologies, so the chained CPI was crafted to allow for a continuously changing basket of goods.Units: Index Points 2003=100, NSASource: Turkish Statistical Institute',
#   '2019-02-08 11:14:30 UTC',
#   '2003-01-31',
#   '2019-01-31'],
#  'UKRFER': ['quandl_ukraine_foreign_exchange_reserves',
#   'The market value of the foreign currency reserves held by Ukraine.Units: USD Million Current Prices, NSASource: National Bank of Ukraine',
#   '2019-02-12 09:37:13 UTC',
#   '2003-01-31',
#   '2019-01-31'],
#  'GRCMPMI': ['quandl_greece_manufacturing_pmi',
#   'This monthly index tracks the health of the manufacturing sector in Greece. Private sector companies report improvement or deterioration in key quantitative indicators like new orders, production, inventories, and employment levels. Responses are amalgamated into an index whose value indicates expansion or contraction of the manufacturing sector. A PMI of 50% means equal numbers of respondents reported improvement and deterioration and there is no change from the previous month; PMIs above and below 50% indicate expansion and contraction of the sector respectively.Units:  SASource: Markit',
#   '2019-02-01 11:29:35 UTC',
#   '2011-06-30',
#   '2019-01-31'],
#  'BELCPIC': ['quandl_belgium_inflation_rate',
#   'The growth rate of the prices in Belgium.Units: percent 2013=100Source: BelgoStat',
#   '2019-01-31 11:41:02 UTC',
#   '1921-01-31',
#   '2019-01-31'],
#  'GEOCPIC': ['quandl_georgia_inflation_rate',
#   'The growth rate of the prices in Georgia.Units: percent 2005=100Source: National Bank of Georgia',
#   '2019-02-04 07:10:30 UTC',
#   '1996-01-31',
#   '2019-01-31'],
#  'IDNCPI': ['quandl_indonesia_consumer_price_index_cpi',
#   'The Consumer Price Index (CPI) is a measure of inflation related to the cost of living. It tracks the prices of essential goods and services like food and healthcare, and weighs those price changes according to their relative importance. The overall change in prices is the inflation rate, which can be positive or negative. The standard CPI fails to account for price drops resulting from improved production technologies, so the chained CPI was crafted to allow for a continuously changing basket of goods.Units: Index Points 2012=100, NSASource: Statistics Indonesia',
#   '2019-02-01 11:29:36 UTC',
#   '1996-01-31',
#   '2019-01-31'],
#  'ITACCPI': ['quandl_italy_core_consumer_prices',
#   'This index tracks prices of consumer goods excluding food, energy and other items with high price volatility.Units: Index Points 2015=100, NSASource: National Institute of Statistics (ISTAT)',
#   '2019-02-08 11:14:21 UTC',
#   '1996-01-31',
#   '2019-01-31'],
#  'ITAHCPI': ['quandl_italy_harmonised_consumer_prices',
#   'Harmonized Indices of Consumer Prices (HICP) are economic indicators that provide official measures of consumer inflation in the Eurozone. These indices track changes in prices to consumer goods and services that are commonly purchased by households. The compilation methodology index is harmonized across EU countries.Units: Index Points 2015=100, NSASource: National Institute of Statistics (ISTAT)',
#   '2019-02-08 11:14:21 UTC',
#   '1996-01-31',
#   '2019-01-31'],
#  'MOZCPI': ['quandl_mozambique_consumer_price_index_cpi',
#   'The Consumer Price Index (CPI) is a measure of inflation related to the cost of living. It tracks the prices of essential goods and services like food and healthcare, and weighs those price changes according to their relative importance. The overall change in prices is the inflation rate, which can be positive or negative. The standard CPI fails to account for price drops resulting from improved production technologies, so the chained CPI was crafted to allow for a continuously changing basket of goods.Units: Index Points 2016=100, NSASource: Instituto Nacional De Estatistica, Mozambique',
#   '2019-01-18 10:48:35 UTC',
#   '1996-01-31',
#   '2019-01-31'],
#  'SVNHCPI': ['quandl_slovenia_harmonised_consumer_prices',
#   'Harmonized Indices of Consumer Prices (HICP) are economic indicators that provide official measures of consumer inflation in the Eurozone. These indices track changes in prices to consumer goods and services that are commonly purchased by households. The compilation methodology index is harmonized across EU countries.Units: Index Points 2015=100, NSASource: Statistical Office of the Republic of Slovenia',
#   '2019-02-12 09:37:11 UTC',
#   '1996-01-31',
#   '2019-01-31'],
#  'VNMCPIC': ['quandl_vietnam_inflation_rate',
#   'The growth rate of the prices in Vietnam.Units: percent Source: General Statistics Office of Vietnam',
#   '2019-01-29 12:18:18 UTC',
#   '1996-01-31',
#   '2019-01-31'],
#  'IDNCCPI': ['quandl_indonesia_core_consumer_prices',
#   'This index tracks prices of consumer goods excluding food, energy and other items with high price volatility.Units: Index Points 2012=100, NSASource: Statistics Indonesia',
#   '2019-02-01 11:29:36 UTC',
#   '2007-12-31',
#   '2019-01-31'],
#  'PAKPPI': ['quandl_pakistan_wholesale_price_index',
#   'This index tracks the average prices domestic producers receive for their output in Pakistan. These are the prices of final goods as they leave the factory gate rather than the prices set by wholesalers and resellers.Units: Index Points 2007-2008=100, NSASource: Pakistan Bureau of Statistics',
#   '2019-02-08 11:14:24 UTC',
#   '1989-01-31',
#   '2019-01-31'],
#  'PRTBCONF': ['quandl_portugal_business_confidence',
#   'This monthly index tracks the outlook of representative firms on the future business climate of Portugal. Units: Index Points Source: Statistics Portugal',
#   '2019-01-30 09:40:31 UTC',
#   '1989-01-31',
#   '2019-01-31'],
#  'NORPPIC': ['quandl_norway_producer_prices_change',
#   'The monthly percent change in the Producer Prices Index of Norway.Units: percent 2000=100Source: Statistics Norway',
#   '2019-02-12 09:37:06 UTC',
#   '2000-12-31',
#   '2019-01-31'],
#  'ITACNCN': ['quandl_italy_consumer_confidence',
#   "This monthly index tracks consumers' opinions about their current economic well-being and outlook for the economy. It provides insight into consumers' short-term spending, saving, and borrowing plans.Units: Index Points 2010=100, SASource: ISAE/ISTAT",
#   '2019-01-30 09:10:52 UTC',
#   '1982-01-31',
#   '2019-01-31'],
#  'MEXCCPI': ['quandl_mexico_core_consumer_prices',
#   'This index tracks prices of consumer goods excluding food, energy and other items with high price volatility.Units: Index Points NSASource: Instituto Nacional de Estadstica y Geografa (INEGI)',
#   '2019-02-08 11:14:23 UTC',
#   '1982-01-31',
#   '2019-01-31'],
#  'TURPPI': ['quandl_turkey_producer_prices',
# ...
#  'RUSMKT': ['quandl_russia_stock_market_micex_',
#   'A stock market index which tracks the performance of a selection of larger and more liquid companies based in Russia.Units: points Source: Moscow Stock Exchange',
#   '2019-02-12 09:37:09 UTC',
#   '1997-09-22',
#   '2019-02-12'],
#  'NZLMKT': ['quandl_new_zealand_stock_market_nzx_50',
#   'A stock market index which tracks the performance of a selection of larger and more liquid companies based in New Zealand.Units: points Source: New Zealand Exchange',
#   '2019-02-12 09:36:36 UTC',
#   '2011-01-21',
#   '2019-02-12'],
#  'GBRMKT': ['quandl_united_kingdom_uk_ftse_100_stock_market_index',
#   'A stock market index which tracks the performance of a selection of larger and more liquid companies based in the United Kingdom.Units: points Source: London Stock Exchange',
#   '2019-02-12 09:37:15 UTC',
#   '1979-07-13',
#   '2019-02-12'],
#  'AGOCUR': ['quandl_angola_angolan_kwanza',
#   'National currency of AngolaSource: OTC Interbank',
#   '2019-02-12 09:36:32 UTC',
#   '1994-12-14',
#   '2019-02-12'],
#  'SGPGYLD': ['quandl_singapore_government_bond_10y',
#   'The average of the yield on ten-year government bonds in Singapore.Units: percent Source: Monetary Authority of Singapore',
#   '2019-02-12 09:36:38 UTC',
#   '1998-06-29',
#   '2019-02-12'],
#  'NZLGYLD': ['quandl_new_zealand_government_bond_10y',
#   'The average of the yield on ten-year government bonds in New Zealand.Units: percent Source: New Zealand Treasury',
#   '2019-02-12 09:36:36 UTC',
#   '1985-03-19',
#   '2019-02-12'],
#  'BELGYLD': ['quandl_belgium_government_bond_10y',
#   'The average of the yield on ten-year government bonds in Belgium.Units: percent Source: Federal Public Service Finance',
#   '2019-02-12 09:36:33 UTC',
#   '1989-06-05',
#   '2019-02-12'],
#  'AZECUR': ['quandl_azerbaijan_azerbaijani_manat',
#   'National currency of AzerbaijanSource: OTC Interbank',
#   '2019-02-12 09:36:32 UTC',
#   '2001-05-07',
#   '2019-02-12'],
#  'BGRCUR': ['quandl_bulgaria_bulgarian_lev',
#   'National currency of BulgariaSource: OTC Interbank',
#   '2019-02-12 09:36:44 UTC',
#   '2002-10-21',
#   '2019-02-12'],
#  'QATGYLD': ['quandl_qatar_government_bond_10y',
#   'The average of the yield on ten-year government bonds in Qatar.Units: percent Source: Qatar Central Bank',
#   '2019-02-12 09:36:39 UTC',
#   '2012-08-22',
#   '2019-02-12'],
#  'AUSGYLD': ['quandl_australia_government_bond_10y',
#   'The average of the yield on ten-year government bonds in Australia.Units: percent Source: Australia Department of Treasury',
#   '2019-02-12 09:36:37 UTC',
#   '1979-10-01',
#   '2019-02-12'],
#  'CPVCUR': ['quandl_cape_verde_escudo',
#   'National currency of Cape VerdeSource: OTC Interbank',
#   '2019-02-12 09:36:36 UTC',
#   '1995-03-03',
#   '2019-02-12'],
#  'CHNMKT': ['quandl_china_shanghai_composite_stock_market_index',
#   'A stock market index which tracks the performance of a selection of larger and more liquid companies based in China.Units: points Source: Shanghai Stock Exchange',
#   '2019-02-12 09:36:54 UTC',
#   '1990-12-19',
#   '2019-02-12'],
#  'AUTCUR': ['quandl_austria_euro_exchange_rate_eur/usd_austria',
#   'National currency of AustriaSource: OTC Interbank',
#   '2019-02-12 09:36:37 UTC',
#   '1979-10-15',
#   '2019-02-12'],
#  'BELCUR': ['quandl_belgium_euro_exchange_rate_eur/usd_belgium',
#   'National currency of BelgiumSource: OTC Interbank',
#   '2019-02-12 09:36:42 UTC',
#   '1979-10-15',
#   '2019-02-12'],
#  'AUSMKT': ['quandl_australia_s&p/asx_200_stock_market_index',
#   'A stock market index which tracks the performance of a selection of larger and more liquid companies based in Australia.Units: points Source: Australian Stock Exchange',
#   '2019-02-12 09:36:44 UTC',
#   '1992-05-29',
#   '2019-02-12'],
#  'USAGYLD': ['quandl_united_states_government_bond_10y',
#   'The average of the yield on ten-year government bonds in the United States.Units: percent Source: U.S. Department of the Treasury',
#   '2019-02-12 09:36:32 UTC',
#   '1979-10-18',
#   '2019-02-12'],
#  'COMFINF': ['quandl_comoros_food_inflation',
#   'The growth rate of food prices in Comoros.Units: Percent 1999=100Source: Banque Centrale des Comores',
#   '2019-02-12 09:36:53 UTC',
#   '2012-01-31',
#   '2014-11-30'],
#  'YEMCCPI': ['quandl_yemen_core_consumer_prices',
#   'This index tracks prices of consumer goods excluding food, energy and other items with high price volatility.Units: Index Points Volume Index, NSASource: Central Bank of Yemen',
#   '2019-02-12 09:37:14 UTC',
#   '2005-01-31',
#   '2014-11-30'],
#  'YEMCPIC': ['quandl_yemen_inflation_rate',
#   'The growth rate of the prices in Yemen.Source: Central Statistics Office, Yemen',
#   '2018-06-04 17:39:46 UTC',
#   '2006-01-31',
#   '2014-11-30'],
#  'SWEIR': ['quandl_sweden_interest_rate',
#   'The daily average of the central bank policy rate in Sweden. This is the interest rate the central bank charges on loans to commercial banks.Units: percent Source: Sveriges Riksbank',
#   '2019-02-13 08:40:32 UTC',
#   '1994-05-26',
#   '2019-02-13'],
#  'CYPM2': ['quandl_cyprus_money_supply_m2',
#   'M1 + savings deposits, small-denomination savings deposits, and retail money market mutual funds.Units: EUR Thousand Current Prices, NSASource: Central Bank of Cyprus',
#   '2019-02-12 09:36:55 UTC',
#   '1997-01-31',
#   '2007-11-30'],
#  'STPCPI': ['quandl_sao_tome_and_principe_sao_tome_and_principe_consumer_price_index_cpi',
#   'The Consumer Price Index (CPI) is a measure of inflation related to the cost of living. It tracks the prices of essential goods and services like food and healthcare, and weighs those price changes according to their relative importance. The overall change in prices is the inflation rate, which can be positive or negative. The standard CPI fails to account for price drops resulting from improved production technologies, so the chained CPI was crafted to allow for a continuously changing basket of goods.Units: Index Points 2014M12=100, NSASource: Central Bank of Sao Tome and Principe',
#   '2019-02-12 09:37:09 UTC',
#   '2005-01-31',
#   '2019-10-31'],
#  'VENEMP': ['quandl_venezuela_employed_persons',
#   'The total number of employed (including self-employed) persons in Venezuela.Units:  Volume, NSASource: National Institute of Statistics, Venezuela',
#   '2019-02-12 09:37:16 UTC',
#   '1999-01-31',
#   '2016-04-30'],
#  'VENUNP': ['quandl_venezuela_unemployed_persons',
#   'The total members of the labor force of Venezuela who are unemployed and actively seeking work.Units:  Volume, NSASource: National Institute of Statistics, Venezuela',
#   '2019-02-12 09:37:16 UTC',
#   '1999-01-31',
#   '2016-04-30'],
#  'VENUNR': ['quandl_venezuela_unemployment_rate',
#   'The percentage of the labor force of Venezuela who are unemployed and actively seeking work.Units: percent Source: National Institute of Statistics, Venezuela',
#   '2018-06-04 17:39:46 UTC',
#   '1999-01-31',
#   '2016-04-30'],
#  'TZAGAGR': ['quandl_tanzania_gdp_annual_growth_rate',
#   'The annual growth rate of GDP in Tanzania.Units: percent Source: National Bureau of Statistics (NBS) - Tanzania',
#   '2019-01-11 15:40:17 UTC',
#   '2002-03-31',
#   '2017-09-30'],
#  'LUXREM': ['quandl_luxembourg_remittances',
#   'The quarterly net value of remittances into Luxembourg. Remittances are monies sent into Luxembourg by workers in foreign countries. Units: EUR Million NSASource: Eurostat',
#   '2019-02-12 09:37:03 UTC',
#   '1995-03-31',
#   '2014-03-31'],
#  'FINREM': ['quandl_finland_remittances',
#   'The quarterly net value of remittances into Finland. Remittances are monies sent into Finland by workers in foreign countries. Units: EUR Million NSASource: Eurostat',
#   '2019-02-12 09:36:58 UTC',
#   '1999-03-31',
#   '2014-03-31'],
#  'MKDGGR': ['quandl_macedonia_gdp_growth_rate',
#   'The growth rate of the GDP of Macedonia.Units: percent Source: State Statistical Office of the Republic of Macedonia',
#   '2019-02-12 09:37:15 UTC',
#   '2004-03-31',
#   '2014-03-31'],
#  'TZAGGR': ['quandl_tanzania_gdp_growth_rate',
#   'The growth rate of the GDP of Tanzania.Units: Percent Source: National Bureau of Statistics (NBS) - Tanzania',
#   '2018-06-04 17:39:41 UTC',
#   '2001-06-30',
#   '2010-09-30'],
#  'POLIR': ['quandl_poland_interest_rate',
#   'The monthly average of the central bank policy rate in Poland. This is the interest rate the central bank charges on loans to commercial banks.Units: percent Source: National Bank of Poland',
#   '2019-02-07 09:54:05 UTC',
#   '1998-02-26',
#   '2019-02-28'],
#  'ALBDIR': ['quandl_albania_overnight_deposit_interest_rate',
#   'Units: percent Source: Bank of Albania',
#   '2019-02-07 09:53:44 UTC',
#   '2005-03-31',
#   '2019-02-28'],
#  'ALBLENDR': ['quandl_albania_overnight_lending_rate',
#   'Units: percent Source: Bank of Albania',
#   '2019-02-07 09:53:44 UTC',
#   '2005-03-31',
#   '2019-02-28'],
#  'DEUCNCN': ['quandl_germany_consumer_confidence',
#   "This monthly index tracks consumers' opinions about their current economic well-being and outlook for the economy. It provides insight into consumers' short-term spending, saving, and borrowing plans.Units: Index Points SASource: GfK Group",
#   '2019-01-31 11:41:11 UTC',
#   '2001-01-31',
#   '2019-02-28'],
#  'USAOPT': ['quandl_united_states_ibd/tipp_economic_optimism_index',
#   "This index measures consumer opinions on the outlook of the national economy in the United States. It is based on a nationwide survey of working-age adults on their personal financial outlook, economic outlook, and confidence in federal economic policies. An index value of 50 indicates no change from the previous survey.Source: Technometrica Market Intelligence/The Investor's Business Daily",
#   '2019-02-08 11:14:31 UTC',
#   '2001-02-28',
#   '2019-02-28'],
#  'RUSMPMI': ['quandl_russia_manufacturing_pmi',
#   'This monthly index tracks the health of the manufacturing sector in Russia. Private sector companies report improvement or deterioration in key quantitative indicators like new orders, production, inventories, and employment levels. Responses are amalgamated into an index whose value indicates expansion or contraction of the manufacturing sector. A PMI of 50% means equal numbers of respondents reported improvement and deterioration and there is no change from the previous month; PMIs above and below 50% indicate expansion and contraction of the sector respectively.Units:  SASource: HSBC',
#   '2019-02-01 11:29:41 UTC',
#   '2011-09-30',
#   '2019-02-28'],
#  'NORIR': ['quandl_norway_interest_rate',
#   'The daily average of the central bank policy rate in Norway. This is the interest rate the central bank charges on loans to commercial banks.Units: percent Source: Norges Bank',
#   '2019-02-07 09:54:04 UTC',
#   '1991-01-01',
#   '2019-02-28'],
#  'ARGMINWG': ['quandl_argentina_minimum_monthly_wage',
#   'The minimum wage in Argentina.Units: ARS/Month Current Prices, NSASource: Ministerio de Economia y Production, Republica Argentina (MECON)',
#   '2019-02-08 11:14:13 UTC',
#   '1965-01-31',
#   '2019-02-28'],
#  'PRKINFR': ['quandl_north_korea_inflation_rate',
#   'The growth rate of the prices in North Korea.Units: percent Source: Daily NK',
#   '2019-02-12 09:37:06 UTC',
#   '2010-08-31',
#   '2013-07-31'],
#  'IRLNO': ['quandl_ireland_new_orders',
#   'The market value of new orders of manufactured goods in Ireland by month.Units: Index Points Seasonally AdjustedSource: Central Statistics Office Ireland',
#   '2018-06-04 16:25:01 UTC',
#   '2000-01-31',
#   '2013-07-31'],
#  'NZLM2': ['quandl_new_zealand_money_supply_m2',
#   'M1 + savings deposits, small-denomination savings deposits, and retail money market mutual funds.Units: NZD Million Current Prices, NSASource: Reserve Bank of New Zealand',
#   '2018-06-04 16:25:20 UTC',
#   '1988-03-31',
#   '2017-01-31'],
#  'NZLCCONF': ['quandl_new_zealand_consumer_credit',
#   'The amount of money owed by residents of a country, including mortgages, bank loans, credit card and other debt.Units: NZD Million Current Prices, NSA',
#   '2018-06-04 16:25:19 UTC',
#   '1990-12-31',
#   '2017-01-31'],
#  'INDBCONF': ['quandl_india_business_confidence',
#   'This quarterly index tracks the outlook of representative firms on the future business climate of India. Units: Index Points Source: Confederation of Indian Industry (CII)',
#   '2018-10-04 01:21:44 UTC',
#   '2005-09-30',
#   '2018-06-30'],
#  'EGYFDI': ['quandl_egypt_foreign_direct_investment',
#   'The value of all investments made by foreign entities directly into companies in Egypt. It does not include foreign purchases of equities on domestic stock exchanges.Units: USD Million Current Prices, NSASource: Central Bank of Egypt',
#   '2018-11-18 02:28:34 UTC',
#   '2002-03-31',
#   '2018-06-30'],
#  'PHLHOUS': ['quandl_philippines_housing_sales',
#   'The total value of real-estate sales during the previous quarter in Philippines.Units: PHP/SQ. METRE Source: National Statistics Office of Philippines',
#   '2018-11-27 02:10:27 UTC',
#   '2002-03-31',
#   '2018-06-30'],
#  'SDNCA': ['quandl_sudan_current_account',
#   'The the sum of the balance of trade (goods and services exports less imports), net income from abroad and net current transfers. A positive value indicates that a country is a net lender to the rest of the world; a negative value indicates that a country is a net borrower.Units: USD Million Source: Central Bank of Sudan',
#   '2018-09-09 01:33:37 UTC',
#   '2002-03-31',
#   '2018-06-30'],
#  'MDACA': ['quandl_moldova_current_account',
#   'The the sum of the balance of trade (goods and services exports less imports), net income from abroad and net current transfers. A positive value indicates that a country is a net lender to the rest of the world; a negative value indicates that a country is a net borrower.Units: USD Million Source: National Bank of Moldova',
#   '2018-10-24 01:34:28 UTC',
#   '1995-03-31',
#   '2018-06-30'],
#  'MDAFDI': ['quandl_moldova_foreign_direct_investment_net_inflows',
#   'The value of all investments made by foreign entities directly into companies in Moldova. It does not include foreign purchases of equities on domestic stock exchanges.Units: USD Million Source: National Bank of Moldova',
#   '2019-02-12 09:37:10 UTC',
#   '1995-03-31',
#   '2018-06-30'],
#  'TTOBOT': ['quandl_trinidad_and_tobago_balance_of_trade',
#   'The quarterly net financial position of Trinidad and Tobago in the global goods and services market, measured as the difference in value between its imports and exports. A negative trade balance indicates imports exceed exports; a positive trade balance indicates exports exceed imports.Units: USD Million Source: Central Bank of Trinidad and Tobago',
#   '2018-12-07 02:14:57 UTC',
#   '1995-03-31',
#   '2018-06-30'],
#  'TTOEXVOL': ['quandl_trinidad_and_tobago_exports',
#   'The total value of the goods and services produced by Trinidad and Tobago and purchased by foreign entities.Units: USD Million Source: Central Bank of Trinidad and Tobago',
#   '2019-02-12 09:37:12 UTC',
#   '1995-03-31',
#   '2018-06-30'],
#  'TTOIMVOL': ['quandl_trinidad_and_tobago_imports',
#   "The total value of a country's imports of physical goods and payments to foreigners for services like shipping and tourism.Units: USD Million Source: Central Bank of Trinidad and Tobago",
#   '2019-02-12 09:37:12 UTC',
#   '1995-03-31',
#   '2018-06-30'],
#  'IRNCSP': ['quandl_iran_consumer_spending',
#   'Total quarterly personal expenditure on goods and services in Iran, excluding interest payments, land purchases, transfers abroad, business expenditures, and purchases of second-hand goods. Units: IRR Billion Constant Prices 2004-05, NSASource: Central Bank of Iran',
#   '2019-02-12 09:37:10 UTC',
#   '1988-03-31',
#   '2018-06-30'],
#  'IRNGCP': ['quandl_iran_gdp_constant_prices',
#   'Inflation adjusted GDP.Units: IRR Billion Source: Central Bank of Iran',
#   '2019-02-12 09:37:10 UTC',
#   '1988-03-31',
#   '2018-06-30'],
#  'IRNGFCF': ['quandl_iran_gross_fixed_capital_formation',
#   'The net value of fixed capital flowing into businesses in Iran, where fixed capital is the value of new fixed capital purchased by businesses less old fixed capital sold or disposed of, ignoring depreciation costs of existing fixed assets.Units: IRR Billion Constant Prices, 2004-2005 NSASource: Central Bank of Iran',
#   '2019-02-12 09:37:10 UTC',
#   '1988-03-31',
#   '2018-06-30'],
#  ...}

# %%
manifest_df["new_name"] = manifest_df["name"].apply(lambda x: unicodedata.normalize("NFKD",x).lower().replace(" - ", "-").replace(" -","").translate(str.maketrans(char_to_replace)))
manifest_df["new_name"].head()
# Out:
# 0    untitled_dataset_2018_05_30_19:16:22
# 1                                 andorra
# 2                          american_samoa
# 3    untitled_dataset_2018_05_30_19:21:08
# 4    euro_area_sentix_investors_sentiment
# Name: new_name, dtype: object

# %%
COUNTRY_MAPPER = OrderedDict(
    {
        "AND": "AD",
        "ALB": "AL",
        "AUT": "AT",
        "BIH": "BA",
        "BEL": "BE",
        "BGR": "BG",
        "BLR": "BY",
        "CHE": "CH",
        "SRB": "CS",
        "MNE": "CS",
        "CYP": "CY",
        "CZE": "CZ",
        "DEU": "DE",
        "DNK": "FO",
        "EST": "EE",
        "ESP": "ES",
        "FIN": "FI",
        "FRA": "FR",
        "GBR": "UK",
        "GRC": "GR",
        "HRV": "HR",
        "HUN": "HU",
        "IRL": "IE",
        "ISL": "IS",
        "ITA": "VA",
        "LIE": "LI",
        "LTU": "LT",
        "LUX": "LU",
        "LVA": "LV",
        "MCO": "MC",
        "MDA": "MD",
        "MKD": "MK",
        "MLT": "MT",
        "NLD": "NL",
        "NOR": "SJ",
        "POL": "PL",
        "PRT": "PT",
        "ROU": "RO",
        "RUS": "RU",
        "SWE": "SE",
        "SVN": "SI",
        "SVK": "SK",
        "TUR": "TR",
        "UKR": "UA",
        "EUR": "XC",
    }
)

manifest_df = pd.read_csv("../data/MacrodataFiles11Oct2022/SGE_TradingEconomics_Metadata.csv")

def prepare_manifest(manifest_df):
    """
    Create a nice CSV file where there is the mapping between QUANDL code and its description.

    :param manifest_df: raw manifest data associated to QUANDL data.
    :return df: final dataframe to be stored.
    """
    char_to_replace = {
        "-": "_",
        " ": "_",
        "(": "",
        ")": "",
    }
    manifest_df["name"] = manifest_df["name"].apply(
        lambda x: unicodedata.normalize("NFKD", x)
        .lower()
        .replace(" - ", "-")
        .replace(" -", "")
        .translate(str.maketrans(char_to_replace))
    )
    manifest_df["quandl_country"] = manifest_df["code"].str[:3]
    manifest_df["ed_country"] = manifest_df["code"].str[:3]
    manifest_df.replace({"ed_country": COUNTRY_MAPPER}, inplace=True)
    return manifest_df

new_df = prepare_manifest(manifest_df)
new_df.head()
# Out:
#         code                                  name  \
# 0  ALBRATING  untitled_dataset_2018_05_30_19:16:22
# 1     ANDCUR                               andorra
# 2     ASMCUR                        american_samoa
# 3  DZARATING  untitled_dataset_2018_05_30_19:21:08
# 4    EURSNTX  euro_area_sentix_investors_sentiment
#
#                                          description refreshed_at from_date  \
# 0                   This dataset has no description.          NaN       NaN
# 1            National currency of COUNTRYUnits: LCU           NaN       NaN
# 2            National currency of COUNTRYUnits: LCU           NaN       NaN
# 3                   This dataset has no description.          NaN       NaN
# 4  This index published by Sentix tracks investor...          NaN       NaN
#
#   to_date quandl_country ed_country
# 0     NaN            ALB         AL
# 1     NaN            AND         AD
# 2     NaN            ASM        ASM
# 3     NaN            DZA        DZA
# 4     NaN            EUR         XC

# %%
new_df[(new_df.code == "SRB&MNEFINF")]
# Out:
# Empty DataFrame
# Columns: [code, name, description, refreshed_at, from_date, to_date, quandl_country, ed_country]
# Index: []

# %%
def prepare_dataset(ds_code, data):
    """
    Clean up key values and make a dataframe out of it for storage.

    :param ds_code: QUANDL code of the dataset.
    :param data: dictionary with data.
    :return df: final dataframe to be stored
    """
    new_data = []
    if len(data) == 0:
        return None
    for k, v in data.items():
        tmp_dict = {}
        tmp_dict["name"] = ds_code
        # tmp_dict["date_time"] = k.to_pydatetime().strftime("%Y-%m-%d")
        tmp_dict["date_time"] = k.to_pydatetime().date()
        # tmp_dict["year"] = k.to_pydatetime().strftime("%Y")
        tmp_dict["value"] = v
        new_data.append(tmp_dict)
    return pd.DataFrame(new_data)

list_dfs=[]
for k, d in macro_econo_df.items():
    # TODO: The SGE label could not be always applicable. Need to re-engineer this part when/if new data from QUANDL is retrieved.
    code = k.replace("SGE/", "").replace(" - Value", "")
    if code in ["ALBRATING", "DZARATING"]:
        # Skip these datasets since there is no description for them.
        continue
    tmp_df = prepare_dataset(code, d)
    if tmp_df is None:
        continue
    list_dfs.append(tmp_df)
df = pd.concat(list_dfs)
df.head()
# Out:
#      name   date_time     value
# 0  ANDGPC  2009-12-31  41860.24
# 1  ANDGPC  2010-12-31  39627.66
# 2  ANDGPC  2011-12-31  38038.88
# 3  ANDGPC  2012-12-31  37967.80
# 4  ANDGPC  2013-12-31  38715.36

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .master("local") \
    .getOrCreate()

spark_df = spark.createDataFrame(df)
# Out:
# /opt/conda/lib/python3.10/site-packages/pyspark/sql/pandas/conversion.py:474: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():
# /opt/conda/lib/python3.10/site-packages/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():

# %%
spark_df.select("name").distinct().show(300)
# Out:
# +---------+
# |     name|
# +---------+
# |   ANDGPC|
# |    ALBCF|
# |  ALBPITR|
# |  AUTCNCN|
# |   AUTFDI|
# |    BGRLC|
# |   CYPGGR|
# |   CZEREM|
# | ESTCCONF|
# |   GRCUNR|
# |   IRLGNP|
# |    MKDGD|
# |  NLDCPIC|
# |    SVKLC|
# |   ALBDIR|
# |   BGRSTR|
# |    CHEM0|
# |    CHECI|
# |  CYPGOLD|
# |   CYPEMP|
# |   DNKFER|
# |  ESTJVAC|
# |    FRACF|
# |  FRAUNRY|
# |   GBRFDI|
# | GRCCPICM|
# | MLTIMVOL|
# |   SWERSM|
# |   SWERSY|
# |  SWEGBVL|
# |  SWEEXPX|
# |   TURGCP|
# | BELIMVOL|
# | CHECPICM|
# |    ESTIP|
# |   ESTFDI|
# |  ESPFACT|
# |   FRACPI|
# |  FRASSRE|
# |   HRVFDI|
# |   HUNEMP|
# |  HUNGPCP|
# |  LTUPSAV|
# |  LUXWAGE|
# |   SWEGSP|
# |  SVKIMPX|
# | TURBCONF|
# |  UKRGAGR|
# |  AUTSSRC|
# |  CYPDINV|
# | FRAIMVOL|
# |   FRAPPI|
# |  GBRLUNR|
# |   GBRGDG|
# |   HUNBLR|
# |  IRLGPCP|
# | NORCPICM|
# |   SWECPI|
# | SWEIMVOL|
# |  SVNGBVL|
# | ALBBCONF|
# |  CYPCARS|
# |    CYPCF|
# | CZEEXVOL|
# | DEUDPINC|
# |  DNKPITR|
# |   ESTMKT|
# |  ESPLUNR|
# |  GBRFACT|
# |  HRVCNCN|
# |  HRVWAGE|
# |  MLTSSRC|
# |    ROUIR|
# |  ROUSSRE|
# |    SWENO|
# |    SVKM3|
# |   TURGDG|
# |  AUTCARS|
# |  BGRSSRC|
# |  BLRWAGE|
# |   CYPCPI|
# |   FRABOT|
# |   HUNCOP|
# |   HUNCPI|
# |   LTUFDI|
# |   LVAGPC|
# |    NLDM2|
# |    POLLC|
# |  SVNUNRY|
# |  SVNGFCF|
# |   SVKBOT|
# |    EURCA|
# |   ALBCPI|
# |  AUTUNRY|
# |    BELM2|
# |  CYPGBGT|
# |  FRACNCN|
# |  GRCJVAC|
# |    HRVIP|
# | HRVCCONF|
# | ISLCPICM|
# | ITAIPMOM|
# |  LVACPIC|
# |  PRTGYLD|
# | SWEEXVOL|
# |  EURGOLD|
# |  AUTGYLD|
# |   AUTGGR|
# |    BELCI|
# | BGRIPMOM|
# |   BLRCSP|
# | DNKCCONF|
# |  ESTHCPI|
# |  ITAGYLD|
# |  LTUGBVL|
# |  RUSDINV|
# |   BIHGGR|
# |   CYPCSP|
# |  CZECINF|
# |  CZEHOUS|
# |     MDAG|
# |  MKDTOUR|
# |   MLTUNR|
# |    SWEBI|
# | SWEDPINC|
# |  SVKGFCF|
# |    TURMP|
# |    UKRCI|
# |    BELCU|
# |  DNKWAGE|
# |    NLDLC|
# |   POLTOT|
# |   ROUREM|
# |     ROUG|
# | TURIPMOM|
# |  EURLUNR|
# |    BELCA|
# |   CZEBOT|
# |  GRCUNRY|
# |   HRVFER|
# |   HUNPOP|
# |   IRLBOT|
# |     ISLG|
# |    LUXM0|
# |    MDAIP|
# |   MLTGSP|
# | POLCPICM|
# |  EURPSAV|
# |   AUTPPI|
# |  BELSSRC|
# |   CHEGSP|
# |     DEUG|
# | DEUCAGDP|
# |   ESPEMP|
# |     FING|
# |  HRVCPIC|
# |   IRLLPS|
# | LIEEXVOL|
# |    LVAIR|
# |    LVACF|
# |  NLDEXPX|
# |   NLDEMP|
# | NLDDPINC|
# |   NORFER|
# | POLMINWG|
# |    PRTM2|
# |  SWEHOUS|
# |  SVNEDBT|
# |    TURIR|
# |    EURM3|
# |  AUTLUNR|
# |   BIHRSY|
# |   DEUFER|
# |   ESTEMP|
# |    FINMP|
# |   FINTOT|
# |    GRCMP|
# |  GRCGAGR|
# |   LUXGSP|
# |   MKDPOP|
# |   MLTGPC|
# |   NLDBLR|
# | NORIPMOM|
# |  NORWAGE|
# |  POLSSRE|
# |  PRTLFPR|
# |   PRTGPC|
# |    TURM3|
# | BLRCCONF|
# |DEUCONPMI|
# |    ESTCA|
# |   IRLPPI|
# |   MDAGPC|
# |   NLDCPI|
# |  NLDUNRY|
# |  NORMPMI|
# | NOREXVOL|
# |  PRTGBGT|
# |  ROUIBOR|
# | ALBGPADM|
# | ALBTERIN|
# |  DEUTOUR|
# |  ESPGAGR|
# |  HUNIMPX|
# |   MDAGDG|
# |   RUSFDI|
# |   EURGCP|
# |   CHEZEW|
# |   DEUGSP|
# |  DNKDINV|
# |  ESTSSRC|
# |    ESPCU|
# |  FRAMPMI|
# |  GBRPSAV|
# |  GRCGBGT|
# |   LTUCSP|
# |    MLTM3|
# |    PRTCU|
# |     PRTG|
# |  SWEGOLD|
# | SWECAGDP|
# |  SVNHCPI|
# |   SVNGSP|
# |  TURCNCN|
# |  BELCNCN|
# |   BELGGR|
# |  BGRGBGT|
# |  DNKGBVL|
# |   ESTUNR|
# |   ESPGDG|
# | FINIMVOL|
# |   GBRFER|
# |   LTUUNR|
# |  LTUSSRC|
# |  MDAWAGE|
# |   MLTFDI|
# |   NORMKT|
# | NORBCONF|
# |   ROUGDG|
# |    SWECA|
# |   BLRLEI|
# |    HRVM0|
# |   ISLSSR|
# |   POLPPI|
# |  SVKCPIC|
# | AUTCCONF|
# |  BLRGFCF|
# |   DEUGGR|
# |  ESTEDBT|
# |  FRAIBOR|
# |  GBRMPMI|
# |    IRLCF|
# |   PRTRSM|
# |   UKRPOP|
# |  CZESSRC|
# | DEUCCONF|
# | ESTMINWG|
# |  ISLTOUR|
# |   ITACPI|
# |  MKDGAGR|
# |  NLDPSAV|
# |   POLGGR|
# |  SWESSRE|
# |ALBMINPRO|
# |  BGRTOUR|
# | BGRMINWG|
# |    BLRM2|
# |   CZEUNP|
# |    GBRM3|
# |   HUNRSY|
# |  LVAGOLD|
# | TURCPICM|
# |  BELLUNR|
# |  CHEGYLD|
# |   CYPPPI|
# |   DNKCSP|
# |   FINEMP|
# |  GBRUNRY|
# |   GBRCSP|
# |  GBRSSRE|
# |    ITANO|
# |   ITARSY|
# |    LTUM1|
# |   NLDCOP|
# | NLDIMVOL|
# |    POLEC|
# |  SVKGOLD|
# |    TURCA|
# |  BELCPIC|
# |    BGRM2|
# |    CYPCA|
# |  ESPCINF|
# |  ISLHCPI|
# |   ITABOT|
# |   LTUGSP|
# |  LTUEXPX|
# |    LUXIR|
# |    LUXM3|
# |  LVACNCN|
# |   MDABOT|
# +---------+
# only showing top 300 rows
