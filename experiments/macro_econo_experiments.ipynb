# %% [markdown]
# # QUANDL
#
# Reading the pickle file I can get a dictionary of dictionaries.
#
# Use the reference from `../data/MacrodataFiles11Oct2022/SGE_TradingEconomics_Metadata.csv` to investigate usage.
#
# Key is composed of `SGE/dataset_code - Value`

# %%
import pandas as pd
import numpy as np
import unicodedata

macro_econo_file= "../data/MacrodataFiles11Oct2022/quandl_datasets.pkl"
macro_econo_df = pd.read_pickle(macro_econo_file)

# %%
manifest_df = pd.read_csv("../data/MacrodataFiles11Oct2022/SGE_TradingEconomics_Metadata.csv")
nice_names = {}
char_to_replace = {'-': '_',
                   ' ': '_',
                   '(':'',
                   ')':'',}
for i, r in manifest_df[["code","name"]].T.to_dict("list").items():
    if r[0] in ["ALBRATING", "DZARATING"]:
        continue
    tmp_dataset_name = unicodedata.normalize(r[1]).lower().replace(" - ", "-").replace(" -","").translate(str.maketrans(char_to_replace))
    clean_dataset_name = f"quandl_{tmp_dataset_name}"
    nice_names[r[0]] = clean_dataset_name

nice_names
# Out:
# {'ANDCUR': 'quandl_andorra',
#  'ASMCUR': 'quandl_american_samoa',
#  'EURSNTX': 'quandl_euro_area_sentix_investors_sentiment',
#  'MACDINV': 'quandl_macau_changes_in_inventories',
#  'MACEMP': 'quandl_macau_employed_persons',
#  'MACGBVL': 'quandl_macau_government_budget_value',
#  'MACGCP': 'quandl_macau_gdp_constant_prices',
#  'MACGFCF': 'quandl_macau_gross_fixed_capital_formation',
#  'MACGSP': 'quandl_macau_government_spending',
#  'MACIP': 'quandl_macau_industrial_production',
#  'MACM1': 'quandl_macau_money_supply_m1',
#  'MACM2': 'quandl_macau_money_supply_m2',
#  'MACPOP': 'quandl_macau_population',
#  'MACRSM': 'quandl_macau_retail_sales_mom',
#  'MACRSY': 'quandl_macau_retail_sales_yoy',
#  'MACUNP': 'quandl_macau_unemployed_persons',
#  'USANFPP': 'quandl_united_states_nonfarm_payrolls_private',
#  'ESPIR': 'quandl_spain_interest_rate',
#  'EURIR': 'quandl_euro_area_interest_rate',
#  'SVNIR': 'quandl_slovenia_interest_rate',
#  'KORIR': 'quandl_south_korea_interest_rate',
#  'MYSIR': 'quandl_malaysia_interest_rate',
#  'MWIIP': 'quandl_malawi_industrial_production',
#  'USACJC': 'quandl_united_states_continuing_jobless_claims',
#  'KENIR': 'quandl_kenya_interest_rate',
#  'GHAIR': 'quandl_ghana_interest_rate',
#  'ARMIR': 'quandl_armenia_interest_rate',
#  'HUNIR': 'quandl_hungary_interest_rate',
#  'FJIIR': 'quandl_fiji_interest_rate',
#  'CHLIR': 'quandl_chile_interest_rate',
#  'USAIR': 'quandl_united_states_fed_funds_rate',
#  'GEOIR': 'quandl_georgia_interest_rate',
#  'MWIIR': 'quandl_malawi_interest_rate',
#  'AUSCBBS': 'quandl_australia_central_bank_balance_sheet',
#  'POLBCONF': 'quandl_poland_business_confidence',
#  'AUSCONPMI': 'quandl_australia_construction_pmi',
#  'VNMRSY': 'quandl_vietnam_retail_sales_yoy',
#  'CHLCPIC': 'quandl_chile_inflation_rate',
#  'CYPCPIC': 'quandl_cyprus_inflation_rate',
#  'GTMCPIC': 'quandl_guatemala_inflation_rate',
#  'MEXIBOR': 'quandl_mexico_28_days_interbank_rate',
#  'DEUSPMI': 'quandl_germany_services_pmi',
#  'GBRSPMI': 'quandl_united_kingdom_services_pmi',
#  'UGACPI': 'quandl_uganda_consumer_price_index_(cpi)',
#  'KORBCONF': 'quandl_south_korea_business_confidence',
#  'FRABCONF': 'quandl_france_business_confidence',
#  'FRANO': 'quandl_france_new_orders_received',
#  'CANPTEMP': 'quandl_canada_part_time_employment_change',
#  'DEUCONPMI': 'quandl_germany_construction_pmi',
#  'GBRCONPMI': 'quandl_united_kingdom_construction_pmi',
#  'USAISMNYI': 'quandl_united_states_ism_new_york_index',
#  'USANFPRPV': 'quandl_united_states_nonfarm_payrolls_private',
#  'FRACNCN': 'quandl_france_consumer_confidence',
#  'CHNSPMI': 'quandl_china_services_pmi',
#  'INDCPIC': 'quandl_india_inflation_rate',
#  'ITAMPMI': 'quandl_italy_manufacturing_pmi',
#  'PAKCNCN': 'quandl_pakistan_consumer_confidence',
#  'PAKCPI': 'quandl_pakistan_consumer_price_index_(cpi)',
#  'USAEMPST': 'quandl_united_states_ny_empire_state_manufacturing_index',
#  'CHNBCONF': 'quandl_china_nbs_manufacturing_pmi',
#  'CHNNO': 'quandl_china_new_orders',
#  'DNKBCONF': 'quandl_denmark_business_confidence',
#  'IDNCPICM': 'quandl_indonesia_inflation_rate_mom',
#  'KENCPIC': 'quandl_kenya_inflation_rate',
#  'PRYCPIC': 'quandl_paraguay_inflation_rate',
#  'RUSBCONF': 'quandl_russia_business_confidence',
#  'IRLCONPMI': 'quandl_ireland_ulster_bank_construction_pmi',
#  'ISLCPICM': 'quandl_iceland_inflation_rate_mom',
#  'CZECNCN': 'quandl_czech_republic_consumer_confidence',
#  'ECUPPI': 'quandl_ecuador_producer_prices',
#  'IDNDIR': 'quandl_indonesia_deposit_facility_rate',
#  'KAZCPI': 'quandl_kazakhstan_consumer_price_index_(cpi)',
#  'KAZPPI': 'quandl_kazakhstan_producer_prices',
#  'LTUPPIC': 'quandl_lithuania_producer_prices_change\xa0',
#  'LVACPIC': 'quandl_latvia_inflation_rate',
#  'ZAFFER': 'quandl_south_africa_foreign_exchange_reserves',
#  'UKRIR': 'quandl_ukraine_interest_rate',
#  'BLRCPI': 'quandl_belarus_consumer_price_index_(cpi)',
#  'CHEBCONF': 'quandl_switzerland_business_confidence',
#  'CHLBOT': 'quandl_chile_balance_of_trade',
#  'CHLEXVOL': 'quandl_chile_exports',
#  'CHLIMVOL': 'quandl_chile_imports',
#  'CYPCARS': 'quandl_cyprus_motor_vehicle_registrations',
#  'DEUBCONF': 'quandl_germany_business_confidence',
#  'EURCPIC': 'quandl_euro_area_inflation_rate',
#  'ISRTOUR': 'quandl_israel_tourist_arrivals',
#  'ITABCONF': 'quandl_italy_business_confidence',
#  'POLFER': 'quandl_poland_foreign_exchange_reserves',
#  'CHEFER': 'quandl_switzerland_foreign_exchange_reserves',
#  'COLPPI': 'quandl_colombia_producer_prices',
#  'KORUNR': 'quandl_south_korea_unemployment_rate',
#  'BLRFER': 'quandl_belarus_foreign_exchange_reserves',
#  'NORCCPI': 'quandl_norway_core_consumer_prices',
#  'ITASPMI': 'quandl_italy_services_pmi',
#  'KORMPMI': 'quandl_south_korea_manufacturing_pmi',
#  'IRLIBOR': 'quandl_ireland_three_month_interbank_rate',
#  'BGRFER': 'quandl_bulgaria_foreign_exchange_reserves',
#  'BLRUNR': 'quandl_belarus_unemployment_rate',
#  'KORCPICM': 'quandl_south_korea_inflation_rate_mom',
#  'CANHSTT': 'quandl_canada_housing_starts',
#  'CRICPIC': 'quandl_costa_rica_inflation_rate',
#  'DNKFER': 'quandl_denmark_foreign_exchange_reserves',
#  'LKATOUR': 'quandl_sri_lanka_tourist_arrivals',
#  'NORPPI': 'quandl_norway_producer_prices',
#  'THACPIC': 'quandl_thailand_inflation_rate',
#  'FRACPIC': 'quandl_france_inflation_rate',
#  'EGYMPMI': 'quandl_egypt_non_oil_private_sector_pmi',
#  'ECUCPIC': 'quandl_ecuador_inflation_rate',
#  'JPNCARS': 'quandl_japan_car_registrations',
#  'PERCPIC': 'quandl_peru_inflation_rate',
#  'COLIR': 'quandl_colombia_interest_rate',
#  'COLCPICM': 'quandl_colombia_inflation_rate_mom',
#  'PERBCONF': 'quandl_peru_business_confidence',
#  'TUNCPIC': 'quandl_tunisia_inflation_rate',
#  'THACNCN': 'quandl_thailand_consumer_confidence',
#  'CHECPIC': 'quandl_switzerland_inflation_rate',
#  'ROUCPIC': 'quandl_romania_inflation_rate',
#  'ISLHOUS': 'quandl_iceland_house_price_index',
#  'NLDMPMI': 'quandl_netherlands_nevi_manufacturing_pmi',
#  'SGPMPMI': 'quandl_singapore_manufacturing_pmi',
#  'CZEBCONF': 'quandl_czech_republic_business_confidence',
#  'FRASPMI': 'quandl_france_services_pmi',
#  'URYCPIC': 'quandl_uruguay_inflation_rate',
#  'AUSIBOR': 'quandl_australia_three_month_interbank_rate',
#  'BRAMINWG': 'quandl_brazil_minimum_monthly_wages',
#  'ETHCPIC': 'quandl_ethiopia_inflation_rate',
#  'PAKCINF': 'quandl_pakistan_core_inflation_rate',
#  'AUSJOBADV': 'quandl_australia_job_advertisements',
#  'MEXPPI': 'quandl_mexico_producer_prices',
#  'RUSCINF': 'quandl_russia_core_inflation_rate',
#  'SVKGBVL': 'quandl_slovakia_government_budget_value',
#  'TURCPI': 'quandl_turkey_consumer_price_index_(cpi)',
#  'UKRFER': 'quandl_ukraine_foreign_exchange_reserves',
#  'GRCMPMI': 'quandl_greece_manufacturing_pmi',
#  'BELCPIC': 'quandl_belgium_inflation_rate',
#  'GEOCPIC': 'quandl_georgia_inflation_rate',
#  'IDNCPI': 'quandl_indonesia_consumer_price_index_(cpi)',
#  'ITACCPI': 'quandl_italy_core_consumer_prices',
#  'ITAHCPI': 'quandl_italy_harmonised_consumer_prices',
#  'MOZCPI': 'quandl_mozambique_consumer_price_index_(cpi)',
#  'SVNHCPI': 'quandl_slovenia_harmonised_consumer_prices',
#  'VNMCPIC': 'quandl_vietnam_inflation_rate',
#  'IDNCCPI': 'quandl_indonesia_core_consumer_prices',
#  'PAKPPI': 'quandl_pakistan_wholesale_price_index',
#  'PRTBCONF': 'quandl_portugal_business_confidence',
#  'NORPPIC': 'quandl_norway_producer_prices_change',
#  'ITACNCN': 'quandl_italy_consumer_confidence',
#  'MEXCCPI': 'quandl_mexico_core_consumer_prices',
#  'TURPPI': 'quandl_turkey_producer_prices',
#  'TWNCINF': 'quandl_taiwan_core_inflation_rate',
#  'TWNPPIC': 'quandl_taiwan_wholesale_prices_change',
#  'ARMCPIC': 'quandl_armenia_inflation_rate',
#  'KAZFER': 'quandl_kazakhstan_foreign_exchange_reserves',
#  'TTOIR': 'quandl_trinidad_and_tobago_interest_rate',
#  'KORCCPI': 'quandl_south_korea_core_consumer_prices',
#  'USANFIB': 'quandl_united_states_nfib_business_optimism_index',
#  'KORCNCN': 'quandl_south_korea_consumer_confidence',
#  'STPIR': 'quandl_sao_tome_and_principe_interest_rate',
#  'SVNBCONF': 'quandl_slovenia_business_confidence',
#  'INDM2': 'quandl_india_money_supply_m2',
#  'FRACMPMI': 'quandl_france_composite_pmi',
#  'INDSPMI': 'quandl_india_services_pmi',
#  'JPNPPIC': 'quandl_japan_producer_prices_change',
#  'PRTCPIC': 'quandl_portugal_inflation_rate',
#  'ZMBCPIC': 'quandl_zambia_inflation_rate',
#  'BRAEXVOL': 'quandl_brazil_exports',
#  'COLCPI': 'quandl_colombia_consumer_price_index_(cpi)',
#  'NLDCNCN': 'quandl_netherlands_consumer_confidence',
#  'NZLIBOR': 'quandl_new_zealand_three_month_interbank_rate',
#  'BELIBOR': 'quandl_belgium_three_month_interbank_rate',
#  'ISLCINF': 'quandl_iceland_core_inflation_rate',
#  'KENFINF': 'quandl_kenya_food_inflation',
#  'RWAFINF': 'quandl_rwanda_food_inflation',
#  'TURCPICM': 'quandl_turkey_inflation_rate_mom',
#  'VNMTOUR': 'quandl_vietnam_tourist_arrivals',
#  'IRLCNCN': 'quandl_ireland_consumer_confidence',
#  'MOZCPICM': 'quandl_mozambique_inflation_rate_mom',
#  'ALBFINF': 'quandl_albania_food_inflation',
#  'DEUMPMI': 'quandl_germany_manufacturing_pmi',
#  'GBRMPMI': 'quandl_united_kingdom_manufacturing_pmi',
#  'JPNMPMI': 'quandl_japan_manufacturing_pmi',
#  'ZMBCPI': 'quandl_zambia_consumer_price_index_cpi',
#  'UGACMPMI': 'quandl_uganda_composite_pmi',
#  'USANMPMI': 'quandl_united_states_non_manufacturing_pmi',
#  'ALBCPIHU': 'quandl_albania__cpi_housing_utilities',
#  'ALBCPIT': 'quandl_albania_cpi_transportation',
#  'DNKCINF': 'quandl_denmark_core_inflation_rate',
#  'JPNLG': 'quandl_japan_bank_lending',
#  'NICCPI': 'quandl_nicaragua_consumer_price_index_(cpi)',
#  'PHLCINF': 'quandl_philippines_core_inflation_rate',
#  'DNKMPMI': 'quandl_denmark_manufacturing_pmi',
#  'PRYBOT': 'quandl_paraguay_balance_of_trade',
#  'PRYEXVOL': 'quandl_paraguay_exports',
#  'PRYIMVOL': 'quandl_paraguay_imports',
#  'SLVCPIC': 'quandl_el_salvador_inflation_rate',
#  'SVNFER': 'quandl_slovenia_foreign_exchange_reserves',
#  'USACHJC': 'quandl_united_states_challenger_job_cuts',
#  'ZAFTVS': 'quandl_south_africa_total_vehicle_sales',
#  'CRIM2': 'quandl_costa_rica_money_supply_m2',
#  'ALBGASP': 'quandl_albania_gasoline_prices',
#  'EURSPMI': 'quandl_euro_area_services_pmi',
#  'BELBCONF': 'quandl_belgium_business_confidence',
#  'BRACPICM': 'quandl_brazil_inflation_rate_mom',
#  'CYPFER': 'quandl_cyprus_foreign_exchange_reserves',
#  'DNKCPI': 'quandl_denmark_consumer_price_index_(cpi)',
#  'ESPBCONF': 'quandl_spain_business_confidence',
#  'MUSCPI': 'quandl_mauritius_consumer_price_index_(cpi)',
#  'NORFER': 'quandl_norway_foreign_exchange_reserves',
#  'PRYMINWG': 'quandl_paraguay_minimum_wages',
#  'SWEUNR': 'quandl_sweden_unemployment_rate',
#  'DEUZEW': 'quandl_germany_zew_economic_sentiment_index',
#  'FRAZEW': 'quandl_france_zew_economic_sentiment_index',
#  'GBRZEW': 'quandl_united_kingdom_zew_economic_sentiment_index',
#  'ITAZEW': 'quandl_italy_zew_economic_sentiment_index',
#  'PERCINF': 'quandl_peru_core_inflation_rate',
#  'RUSCPIC': 'quandl_russia_inflation_rate',
#  'VNMFDI': 'quandl_vietnam_foreign_direct_investment',
#  'CHLBCONF': 'quandl_chile_business_confidence',
#  'INDMPMI': 'quandl_india_manufacturing_pmi',
#  'MEXMPMI': 'quandl_mexico_manufacturing_pmi',
#  'NORCARS': 'quandl_norway_car_registrations',
#  'THACCPI': 'quandl_thailand_core_consumer_prices',
#  'TURLENDR': 'quandl_turkey_overnight_lending_rate',
#  'EGYCINF': 'quandl_egypt_core_inflation_rate',
#  'CANUNR': 'quandl_canada_unemployment_rate',
#  'KORBOT': 'quandl_south_korea_balance_of_trade',
#  'KORCPIC': 'quandl_south_korea_inflation_rate',
#  'KOREXVOL': 'quandl_south_korea_exports',
#  'KORIMVOL': 'quandl_south_korea_imports',
#  'URYIBOR': 'quandl_uruguay_six_month_interbank_rate',
#  'JPNSPMI': 'quandl_japan_services_pmi',
#  'CANCNCN': 'quandl_canada_consumer_confidence',
#  'COLCPIC': 'quandl_colombia_inflation_rate',
#  'BRABOT': 'quandl_brazil_balance_of_trade',
#  'BRAIMVOL': 'quandl_brazil_imports',
#  'TWNCPI': 'quandl_taiwan_consumer_price_index_(cpi)',
#  'CHNBLR': 'quandl_china_prime_lending_rate',
#  'SYCCPIC': 'quandl_seychelles_inflation_rate',
#  'TWNPPI': 'quandl_taiwan_wholesale_prices',
#  'ZAFMPMI': 'quandl_south_africa_manufacturing_pmi',
#  'IRLSPMI': 'quandl_ireland_services_pmi',
#  'SVNCNCN': 'quandl_slovenia_consumer_confidence',
#  'MLTBCONF': 'quandl_malta_business_confidence',
#  'GBRFACT': 'quandl_united_kingdom_cbi_industrial_trends_orders',
#  'MMRMPMI': 'quandl_myanmar_manufacturing_pmi',
#  'THAMPMI': 'quandl_thailand_manufacturing_pmi',
#  'FJICPI': 'quandl_fiji_consumer_price_index_cpi',
#  'ALBCPI': 'quandl_albania_consumer_price_index_(cpi)',
#  'BHRIR': 'quandl_bahrain_interest_rate',
#  'RUSTVS': 'quandl_russia_total_vehicle_sales',
#  'SWESPMI': 'quandl_sweden_services_pmi',
#  'CANBCONF': 'quandl_canada_business_confidence',
#  'ESTCPIC': 'quandl_estonia_inflation_rate',
#  'EURDIR': 'quandl_euro_area_euro_area_deposit_facilty_rate',
#  'EURZEW': 'quandl_euro_area_zew_economic_sentiment_index',
#  'KAZPPIC': 'quandl_kazakhstan_producer_prices_change',
#  'LTUIBOR': 'quandl_lithuania_three_month_interbank_rate',
#  'LUXFER': 'quandl_luxembourg_foreign_exchange_reserves',
#  'TWNCNCN': 'quandl_taiwan_consumer_confidence',
#  'TZACPIC': 'quandl_tanzania_inflation_rate',
#  'EURMPMI': 'quandl_euro_area_manufacturing_pmi',
#  'RUSSPMI': 'quandl_russia_services_pmi',
#  'ALBCPICM': 'quandl_albania_inflation_rate_mom',
#  'BLRCPIC': 'quandl_belarus_inflation_rate',
#  'CZEGBVL': 'quandl_czech_republic_government_budget_value',
#  'DEUUNCH': 'quandl_germany_unemployment_change\xa0',
#  'ESPHCPI': 'quandl_spain_harmonised_consumer_prices',
#  'ESTCPI': 'quandl_estonia_consumer_price_index_(cpi)',
#  'HNDCPI': 'quandl_honduras_consumer_price_index_(cpi)',
#  'HUNCPIC': 'quandl_hungary_inflation_rate',
#  'HUNGBVL': 'quandl_hungary_government_budget_value',
#  'RUSCPI': 'quandl_russia_consumer_price_index_(cpi)',
#  'FJICPIC': 'quandl_fiji_inflation_rate',
#  'NORCINF': 'quandl_norway_core_inflation_rate',
#  'MUSCPIC': 'quandl_mauritius_inflation_rate',
#  'COLPPIC': 'quandl_colombia_producer_prices_change',
#  'IDNCNCN': 'quandl_indonesia_consumer_confidence',
#  'IDNFER': 'quandl_indonesia_foreign_exchange_reserves',
#  'PERCNCN': 'quandl_peru_consumer_confidence',
#  'AUTBCONF': 'quandl_austria_business_confidence',
#  'BELCNCN': 'quandl_belgium_consumer_confidence',
#  'EURBCONF': 'quandl_euro_area_business_climate_indicator',
#  'EURCCPT': 'quandl_euro_area_euro_area_consumer_confidence_price_trends',
#  'EURCNCN': 'quandl_euro_area_consumer_confidence',
#  'EUROPT': 'quandl_euro_area_euro_area_economic_sentiment_indicator',
#  'GRCBCONF': 'quandl_greece_business_confidence',
#  'GRCCNCN': 'quandl_greece_consumer_confidence',
#  'LKACPI': 'quandl_sri_lanka_consumer_price_index_(cpi)',
#  'LUXBCONF': 'quandl_luxembourg_business_confidence',
#  'NLDBCONF': 'quandl_netherlands_business_confidence',
#  'NZLIR': 'quandl_new_zealand_interest_rate',
#  'USANAHB': 'quandl_united_states_nahb_housing_market_index',
#  'ZAFCIDX': 'quandl_south_africa_sacci_business_confidence_index',
#  'HKGFER': 'quandl_hong_kong_foreign_exchange_reserves',
#  'ESPCPI': 'quandl_spain_consumer_price_index_(cpi)',
#  'HRVCNCN': 'quandl_croatia_consumer_confidence',
#  'ZMBCMPMI': 'quandl_zambia_composite_pmi',
#  'SGPBLR': 'quandl_singapore_prime_lending_rate',
#  'TWNCPICM': 'quandl_taiwan_inflation_rate_mom\xa0',
#  'DOMIR': 'quandl_dominican_republic_interest_rate',
#  'USASPMI': 'quandl_united_states_services_pmi',
#  'IDNPPI': 'quandl_indonesia_producer_prices',
#  'KORFER': 'quandl_south_korea_foreign_exchange_reserves',
#  'NLDCPIC': 'quandl_netherlands_inflation_rate',
#  'HUNCINF': 'quandl_hungary_core_inflation_rate',
#  'SWEMPMI': 'quandl_sweden_manufacturing_pmi',
#  'LTUBCONF': 'quandl_lithuania_business_confidence',
#  'USAWAGE': 'quandl_united_states_average_hourly_wages',
#  'BRACARP': 'quandl_brazil_car_production',
#  'BRACARS': 'quandl_brazil_new_vehicle_registrations',
#  'ITACPI': 'quandl_italy_consumer_price_index_(cpi)',
#  'JPNFER': 'quandl_japan_foreign_exchange_reserves',
#  'PAKBOT': 'quandl_pakistan_balance_of_trade',
#  'PAKCPIC': 'quandl_pakistan_inflation_rate',
#  'PHLCPI': 'quandl_philippines_consumer_price_index_(cpi)',
#  'ZAFBLR': 'quandl_south_africa_prime_overdraft_rate',
#  'ISLCPIC': 'quandl_iceland_inflation_rate',
#  'ESPCNCN': 'quandl_spain_consumer_confidence',
#  'ARGCNCN': 'quandl_argentina_consumer_confidence',
#  'BELCPI': 'quandl_belgium_consumer_price_index_(cpi)',
#  'CHEUNP': 'quandl_switzerland_unemployed_persons',
#  'CHLCPICM': 'quandl_chile_inflation_rate_mom\xa0',
#  'CYPCPI': 'quandl_cyprus_consumer_price_index_(cpi)',
#  'DEUCPIC': 'quandl_germany_inflation_rate',
#  'DEUCPICM': 'quandl_germany_inflation_rate_mom',
#  'DEUJVAC': 'quandl_germany_job_vacancies',
#  'DEUUNP': 'quandl_germany_unemployed_persons',
#  'GBRBLR': 'quandl_united_kingdom_prime_lending_rate',
#  'GTMCPI': 'quandl_guatemala_consumer_price_index_(cpi)',
#  'NORCPI': 'quandl_norway_consumer_price_index_(cpi)',
#  'NORCPIC': 'quandl_norway_inflation_rate',
#  'URYCPI': 'quandl_uruguay_consumer_price_index_(cpi)',
#  'USABLR': 'quandl_united_states_average_monthly_prime_lending_rate',
#  'USAEMP': 'quandl_united_states_employed_persons',
#  'USAGPAY': 'quandl_united_states_government_payrolls',
#  'USALFPR': 'quandl_united_states_labor_force_participation_rate',
#  'USAMANWG': 'quandl_united_states_average_hourly_wages_in_manufacturing',
#  'USAMPAY': 'quandl_united_states_manufacturing_payrolls',
#  'USAUNP': 'quandl_united_states_unemployed_persons',
#  'TWNFER': 'quandl_taiwan_foreign_exchange_reserves',
#  'IDNLENDR': 'quandl_indonesia_lending_facility_rate',
#  'CZEJVAC': 'quandl_czech_republic_job_vacancies',
#  'THABCONF': 'quandl_thailand_business_confidence',
#  'NGAMPMI': 'quandl_nigeria_manufacturing_pmi',
#  'NGASPMI': 'quandl_nigeria_non_manufacturing_pmi',
#  'POLMPMI': 'quandl_poland_manufacturing_pmi',
#  'ZMBFINF': 'quandl_zambia_food_inflation',
#  'AUSIR': 'quandl_australia_interest_rate',
#  'ESTCPICM': 'quandl_estonia_inflation_rate_mom',
#  'PERBLR': 'quandl_peru_bank_savings_rate',
#  'RUSCPICM': 'quandl_russia_inflation_rate_mom',
#  'USACNCN': 'quandl_united_states_consumer_sentiment',
#  'BRABCONF': 'quandl_brazil_business_confidence',
#  'MEXBCONF': 'quandl_mexico_business_confidence',
#  'TURCNCN': 'quandl_turkey_consumer_confidence',
#  'BRAMPMI': 'quandl_brazil_manufacturing_pmi',
#  'EURCMPMI': 'quandl_euro_area_euro_area_composite_pmi',
#  'USAMPMI': 'quandl_united_states_manufacturing_pmi',
#  'ESPCPICM': 'quandl_spain_inflation_rate_mom',
#  'LVAFER': 'quandl_latvia_foreign_exchange_reserves',
#  'BGRBCONF': 'quandl_bulgaria_business_confidence',
#  'EURCINF': 'quandl_euro_area_core_inflation_rate',
#  'ITACINF': 'quandl_italy_core_inflation_rate',
#  'RWACPIC': 'quandl_rwanda_inflation_rate',
#  'SVKCNCN': 'quandl_slovakia_consumer_confidence',
#  'IDNCINF': 'quandl_indonesia_core_inflation_rate',
#  'CZEUNP': 'quandl_czech_republic_unemployed_persons',
#  'CZEUNR': 'quandl_czech_republic_unemployment_rate',
#  'DNKHCPI': 'quandl_denmark_harmonised_consumer_prices',
#  'FRACPI': 'quandl_france_consumer_price_index_(cpi)',
#  'FRAHCPI': 'quandl_france_harmonised_consumer_prices',
#  'PERMINWG': 'quandl_peru_minimum_monthly_wage',
#  'TURDIR': 'quandl_turkey_overnight_borrowing_rate',
#  'LBNMPMI': 'quandl_lebanon_pmi',
#  'USACMPMI': 'quandl_united_states_composite_pmi',
#  'GBRHOUS': 'quandl_united_kingdom_house_price_index',
#  'IRLUNR': 'quandl_ireland_unemployment_rate',
#  'IRLUNRY': 'quandl_ireland_youth_unemployment_rate',
#  'MEXCINF': 'quandl_mexico_core_inflation_rate',
#  'NORUNP': 'quandl_norway_unemployed_persons',
#  'PERFER': 'quandl_peru_foreign_exchange_reserves',
#  'AUTIBOR': 'quandl_austria_three_month_interbank_rate',
#  'PRYCPI': 'quandl_paraguay_consumer_price_index_cpi',
#  'SVNIBOR': 'quandl_slovenia_three_month_interbank_rate',
#  'MYSMPMI': 'quandl_malaysia_manufacturing_pmi',
#  'CANLFPR': 'quandl_canada_labor_force_participation_rate',
#  'CRICPI': 'quandl_costa_rica_consumer_price_index_(cpi)',
#  'KORCINF': 'quandl_south_korea_core_inflation_rate',
#  'THACPI': 'quandl_thailand_consumer_price_index_(cpi)',
#  'TURBCONF': 'quandl_turkey_business_confidence',
#  'EGYCPICM': 'quandl_egypt_inflation_rate_mom',
#  'ITACPICM': 'quandl_italy_inflation_rate_mom',
#  'PHLCPICM': 'quandl_philippines_inflation_rate_mom',
#  'BRACPIC': 'quandl_brazil_inflation_rate',
#  'CHECPICM': 'quandl_switzerland_inflation_rate_mom',
#  'NORCPICM': 'quandl_norway_inflation_rate_mom\xa0',
#  'ECUCPI': 'quandl_ecuador_consumer_price_index_(cpi)',
#  'MEXCPI': 'quandl_mexico_consumer_price_index_(cpi)',
#  'PERCPI': 'quandl_peru_consumer_price_index_(cpi)',
#  'MEXCNCN': 'quandl_mexico_consumer_confidence',
#  'USAADP': 'quandl_united_states_adp_employment_change',
#  'GBRCARS': 'quandl_united_kingdom_car_registrations',
#  'ITACPIC': 'quandl_italy_inflation_rate',
#  'TUNCPI': 'quandl_tunisia_consumer_price_index_(cpi)',
#  'VENFER': 'quandl_venezuela_foreign_exchange_reserves',
#  'USAHRS': 'quandl_united_states_average_weekly_hours',
#  'UZBIR': 'quandl_uzbekistan_interest_rate',
#  'CRIFER': 'quandl_costa_rica_foreign_exchange_reserves',
#  'IRLMPMI': 'quandl_ireland_manufacturing_pmi',
#  'USABCONF': 'quandl_united_states_ism_purchasing_managers_index_(pmi)',
#  'USAUNR': 'quandl_united_states_unemployment_rate',
#  'HUNMPMI': 'quandl_hungary_manufacturing_pmi',
#  'CHEZEW': 'quandl_switzerland_zew_economic_sentiment_index\xa0',
#  'USAPFED': 'quandl_united_states_philadelphia_fed_manufacturing_index',
#  'NORMPMI': 'quandl_norway_manufacturing_pmi',
#  'PHLMPMI': 'quandl_philippines_manufacturing_pmi',
#  'VNMCPI': 'quandl_vietnam_consumer_price_index_(cpi)',
#  'CZECPICM': 'quandl_czech_republic_inflation_rate_mom',
#  'IDNMPMI': 'quandl_indonesia_manufacturing_pmi',
#  'UGABCONF': 'quandl_uganda_business_confidence',
#  'VNMMPMI': 'quandl_vietnam_manufacturing_pmi',
#  'FRACPICM': 'quandl_france_inflation_rate_mom',
#  'HUNCPICM': 'quandl_hungary_inflation_rate_mom',
#  'KENCPI': 'quandl_kenya_consumer_price_index_(cpi)',
#  'KGZFER': 'quandl_kyrgyzstan_foreign_exchange_reserves',
#  'MOZCPIC': 'quandl_mozambique_inflation_rate',
#  'VNMIP': 'quandl_vietnam_industrial_production',
#  'AUSCNCN': 'quandl_australia_consumer_confidence',
#  'UGACPIC': 'quandl_uganda_inflation_rate',
#  'UGAFINF': 'quandl_uganda_food_inflation',
#  'MKDIR': 'quandl_macedonia_interest_rate',
#  'CHNCMPMI': 'quandl_china_composite_pmi',
#  'MUSFINF': 'quandl_mauritius_food_inflation',
#  'SGPCMPMI': 'quandl_singapore_private_sector_pmi',
#  'ZAFCMPMI': 'quandl_south_africa_standard_bank_pmi',
#  'ROUBCONF': 'quandl_romania_business_confidence',
#  'ALBCPIC': 'quandl_albania_inflation_rate',
#  'AUSINFEX': 'quandl_australia_inflation_expectations',
#  'CHEMPMI': 'quandl_switzerland_manufacturing_pmi',
#  'CHEUNR': 'quandl_switzerland_unemployment_rate',
#  'CRIPPI': 'quandl_costa_rica_producer_prices',
#  'GTMFER': 'quandl_guatemala_foreign_exchange_reserves',
#  'GTMM0': 'quandl_guatemala_money_supply_m0',
#  'GTMM1': 'quandl_guatemala_money_supply_m1',
#  'GTMM2': 'quandl_guatemala_money_supply_m2',
#  'ISRFER': 'quandl_israel_foreign_exchange_reserves',
#  'LVACPICM': 'quandl_latvia_inflation_rate_mom',
#  'THAPPI': 'quandl_thailand_producer_prices',
#  'UKRCPIC': 'quandl_ukraine_inflation_rate',
#  'CANEC': 'quandl_canada_employment_change',
#  'CANFTEMP': 'quandl_canada_full_time_employment',
#  'CRICPICM': 'quandl_costa_rica_inflation_rate_mom',
#  'THACPICM': 'quandl_thailand_inflation_rate_mom',
#  'PERPPI': 'quandl_peru_producer_prices',
#  'AUTFER': 'quandl_austria_foreign_exchange_reserves',
#  'MUSFER': 'quandl_mauritius_foreign_exchange_reserves',
#  'CHNMPMI': 'quandl_china_caixin_manufacturing_pmi',
#  'MEXCPICM': 'quandl_mexico_inflation_rate_mom',
#  'PERCPICM': 'quandl_peru_inflation_rate_mom',
#  'HRVBCONF': 'quandl_croatia_business_confidence',
#  'DNKCPIC': 'quandl_denmark_inflation_rate',
#  'TWNCCPI': 'quandl_taiwan_core_consumer_prices',
#  'KAZCPIC': 'quandl_kazakhstan_inflation_rate',
#  'RUSFER': 'quandl_russia_foreign_exchange_reserves',
#  'SVKFER': 'quandl_slovakia_foreign_exchange_reserves',
#  'AUSMPMI': 'quandl_australia_manufacturing_pmi',
#  'CYPBCONF': 'quandl_cyprus_business_confidence',
#  'CYPCNCN': 'quandl_cyprus_consumer_confidence',
#  'ESTBCONF': 'quandl_estonia_business_confidence',
#  'ESTCNCN': 'quandl_estonia_consumer_confidence',
#  'LTUCNCN': 'quandl_lithuania_consumer_confidence',
#  'ROUCNCN': 'quandl_romania_consumer_confidence',
#  'AUTMPMI': 'quandl_austria_manufacturing_pmi',
#  'MEXCPIC': 'quandl_mexico_inflation_rate',
#  'JPNCNCN': 'quandl_japan_consumer_confidence',
#  'THACINF': 'quandl_thailand_core_inflation_rate',
#  'IDNCPIC': 'quandl_indonesia_inflation_rate',
#  'PRTCNCN': 'quandl_portugal_consumer_confidence',
#  'SVNCPIC': 'quandl_slovenia_inflation_rate',
#  'USAEARN': 'quandl_united_states_average_hourly_earnings',
#  'AUSSPMI': 'quandl_australia_performance_services_index',
#  'INDBLR': 'quandl_india_prime_lending_rate',
#  'BELCARS': 'quandl_belgium_new_registered_private_cars',
#  'BOLCPI': 'quandl_bolivia_consumer_price_index_(cpi)',
#  'NGACMPMI': 'quandl_nigeria_stanbic_ibtc_bank_pmi',
#  'ISRCNCN': 'quandl_israel_consumer_confidence',
#  'SDNCPIC': 'quandl_sudan_inflation_rate',
#  'ISRBCONF': 'quandl_israel_business_confidence',
#  'AUTJVAC': 'quandl_austria_job_vacancies',
#  'AUTUNP': 'quandl_austria_unemployed_persons',
#  'AUTUNR': 'quandl_austria_unemployment_rate',
#  'CANBLR': 'quandl_canada_prime_lending_rate',
#  'FINCARS': 'quandl_finland_car_registrations',
#  'ISLBOT': 'quandl_iceland_balance_of_trade',
#  'ISLEXVOL': 'quandl_iceland_exports',
#  'ISLIMVOL': 'quandl_iceland_imports',
#  'ITAIBOR': 'quandl_italy_average_three_month_interbank_rate',
#  'MEXMINWG': 'quandl_mexico_minimum_daily_wage',
#  'NGAFER': 'quandl_nigeria_foreign_exchange_reserves',
#  'PHLFER': 'quandl_philippines_foreign_exchange_reserves',
#  'THAFER': 'quandl_thailand_foreign_exchange_reserves',
#  'TWNCPIC': 'quandl_taiwan_inflation_rate',
#  'ZAFCARS': 'quandl_south_africa_new_car_sales',
#  'AUTCNCN': 'quandl_austria_consumer_confidence',
#  'FINCNCN': 'quandl_finland_consumer_confidence',
#  'AUSBCONF': 'quandl_australia_business_confidence',
#  'ISLCCPI': 'quandl_iceland_core_consumer_prices',
#  'RWACPI': 'quandl_rwanda_consumer_price_index_cpi',
#  'GHACMPMI': 'quandl_ghana_composite_pmi',
#  'DNKCNCN': 'quandl_denmark_consumer_confidence',
#  'BELCPICM': 'quandl_belgium_inflation_rate_mom',
#  'TURPPIC': 'quandl_turkey_producer_prices_change',
#  'AZECPICM': 'quandl_azerbaijan_inflation_rate_mom',
#  'UKRCPI': 'quandl_ukraine_consumer_price_index_(cpi)',
#  'UKRCPICM': 'quandl_ukraine_inflation_rate_mom\xa0',
#  'AZECPIC': 'quandl_azerbaijan_inflation_rate',
#  'CHNNMPMI': 'quandl_china_non_manufacturing_pmi',
#  'MDACPIC': 'quandl_moldova_inflation_rate',
#  'NAMIR': 'quandl_namibia_interest_rate',
#  'SYCCPI': 'quandl_seychelles_consumer_price_index_cpi',
#  'SYCFINF': 'quandl_seychelles_food_inflation',
#  'TUNFINF': 'quandl_tunisia_food_inflation',
#  'TURCU': 'quandl_turkey_capacity_utilization',
#  'TUROPT': 'quandl_turkey_economic_confidence_index',
#  'DNKCCPI': 'quandl_denmark_core_consumer_prices',
#  'GEOCPI': 'quandl_georgia_consumer_price_index_(cpi)',
#  'HUNBLR': 'quandl_hungary_interest_rate_on_collateralized_loans',
#  'JPNEWS': 'quandl_japan_economy_watchers_survey',
#  'PAKPPIC': 'quandl_pakistan_wholesale_prices_change',
#  'PHLCCPI': 'quandl_philippines_core_consumer_prices',
#  'POLCNCN': 'quandl_poland_consumer_confidence',
#  'ROUFER': 'quandl_romania_foreign_exchange_reserves',
#  'SVNCPI': 'quandl_slovenia_consumer_price_index_(cpi)',
#  'AREMPMI': 'quandl_united_arab_emirates_manufacturing_pmi',
#  'BRACMPMI': 'quandl_brazil_composite_pmi',
#  'BRASPMI': 'quandl_brazil_services_pmi',
#  'CZEMPMI': 'quandl_czech_republic_manufacturing_pmi',
#  'ETHCPI': 'quandl_ethiopia_consumer_price_index_cpi',
#  'HKGMPMI': 'quandl_hong_kong_private_sector_pmi',
#  'SAUMPMI': 'quandl_saudi_arabia_non_oil_private_sector_pmi',
#  'TURMPMI': 'quandl_turkey_manufacturing_pmi',
#  'TWNMPMI': 'quandl_taiwan_manufacturing_pmi',
#  'SWEBCONF': 'quandl_sweden_business_confidence',
#  'ARMCPI': 'quandl_armenia_consumer_price_index_(cpi)',
#  'CZECPIC': 'quandl_czech_republic_inflation_rate',
#  'CZEFER': 'quandl_czech_republic_foreign_exchange_reserves',
#  'FINBCONF': 'quandl_finland_business_confidence',
#  'LVACPI': 'quandl_latvia_consumer_price_index_(cpi)',
#  'NICCPIC': 'quandl_nicaragua_inflation_rate',
#  'SLVCPI': 'quandl_el_salvador_consumer_price_index_(cpi)',
#  'SVKBCONF': 'quandl_slovakia_business_confidence',
#  'SWECNCN': 'quandl_sweden_consumer_confidence',
#  'USATVS': 'quandl_united_states_total_vehicle_sales',
#  'DEUCMPMI': 'quandl_germany_composite_pmi',
#  'LUXCNCN': 'quandl_luxembourg_consumer_confidence',
#  'KORHOUS': 'quandl_south_korea_house_price_index',
#  'LKACPIC': 'quandl_sri_lanka_inflation_rate',
#  'MYSFER': 'quandl_malaysia_foreign_exchange_reserves',
#  'SLVFER': 'quandl_el_salvador_foreign_exchange_reserves',
#  'ESPCPIC': 'quandl_spain_inflation_rate',
#  'USACPMI': 'quandl_united_states_chicago_pmi',
#  'DNKBR': 'quandl_denmark_bankruptcies',
#  'ISLCPI': 'quandl_iceland_consumer_price_index_(cpi)',
#  'PERCCPI': 'quandl_peru_core_consumer_prices',
#  'VNMBOT': 'quandl_vietnam_balance_of_trade',
#  'VNMEXVOL': 'quandl_vietnam_exports',
#  'VNMIMVOL': 'quandl_vietnam_imports',
#  'MLTCNCN': 'quandl_malta_consumer_confidence',
#  'CANMPMI': 'quandl_canada_manufacturing_pmi',
#  'ESPMPMI': 'quandl_spain_manufacturing_pmi',
#  'ESPSPMI': 'quandl_spain_services_pmi',
#  'FRAMPMI': 'quandl_france_manufacturing_pmi',
#  'KENMPMI': 'quandl_kenya_cfc_stanbic_bank_pmi',
#  'ESPUNCH': 'quandl_spain_unemployment_change',
#  'PRTCPICM': 'quandl_portugal_inflation_rate_mom',
#  'INDM3': 'quandl_india_money_supply_m3',
#  'SGPFER': 'quandl_singapore_foreign_exchange_reserves',
#  'DNKIR': 'quandl_denmark_interest_rate',
#  'DEUIBOR': 'quandl_germany_three_month_interbank_rate',
#  'KORCPI': 'quandl_south_korea_consumer_price_index_(cpi)',
#  'TURCPIC': 'quandl_turkey_inflation_rate',
#  'GBRCNCN': 'quandl_united_kingdom_consumer_confidence',
#  'USANFP': 'quandl_united_states_non_farm_payrolls',
#  'EGYCPIC': 'quandl_egypt_inflation_rate',
#  'PHLCPIC': 'quandl_philippines_inflation_rate',
#  'BGRIR': 'quandl_bulgaria_interest_rate',
#  'USAMAPL': 'quandl_united_states_mba_mortgage_applications',
#  'USACOSC': 'quandl_united_states_crude_oil_stocks_change',
#  'USANATGSC': 'quandl_united_states_natural_gas_stocks_change\xa0',
#  'AZEIR': 'quandl_azerbaijan_interest_rate',
#  'USAMORTG': 'quandl_united_states_mba_30_yr_mortgage_rate',
#  'USAGASSC': 'quandl_united_states_gasoline_stocks_change\xa0',
#  'INDIBOR': 'quandl_india_treasury_bill_91_day_yield',
#  'INDFER': 'quandl_india_foreign_exchange_reserves',
#  'USAJCLM': 'quandl_united_states_initial_jobless_claims',
#  'JPNFBI': 'quandl_japan_foreign_bond_investment',
#  'JPNFSI': 'quandl_japan_investment_by_foreigners',
#  'HNDIR': 'quandl_honduras_interest_rate',
#  'TJKIR': 'quandl_tajikistan_interest_rate',
#  'ALBIR': 'quandl_albania_interest_rate',
#  'ISLIR': 'quandl_iceland_interest_rate',
#  'MDAIR': 'quandl_moldova_interest_rate',
#  'THAIR': 'quandl_thailand_interest_rate',
#  'BRAIR': 'quandl_brazil_interest_rate',
#  'BLRIR': 'quandl_belarus_interest_rate',
#  'GHAJVAC': 'quandl_ghana_job_vacancies',
#  'HRVPSAV': 'quandl_croatia_personal_savings',
#  'EGYDINV': 'quandl_egypt_changes_in_inventories',
#  'BHRCSP': 'quandl_bahrain_consumer_spending',
#  'BHRDINV': 'quandl_bahrain_changes_in_inventories',
#  'BHRGD': 'quandl_bahrain_gdp_deflator',
#  'BHRGFCF': 'quandl_bahrain_gross_fixed_capital_formation',
#  'BHRGSP': 'quandl_bahrain_government_spending',
#  'MACCAGDP': 'quandl_macau_current_account_to_gdp',
#  'MWIGFCF': 'quandl_malawi_gross_fixed_capital_formation',
#  'MWIGSP': 'quandl_malawi_government_spending',
#  'NCLCA': 'quandl_new_caledonia_current_account',
#  'ARMCAGDP': 'quandl_armenia_current_account_to_gdp',
#  'ARMGBGT': 'quandl_armenia_government_budget',
#  'HKGGDG': 'quandl_hong_kong_government_debt_to_gdp',
#  'IRQCA': 'quandl_iraq_current_account',
#  'TWNGBGT': 'quandl_taiwan_government_budget',
#  'BENCA': 'quandl_benin_current_account',
#  'TWNGBVL': 'quandl_taiwan_government_budget_value',
#  'TJKEMP': 'quandl_tajikistan_employed_persons',
#  'PRIG': 'quandl_puerto_rico_gdp',
#  'PRIGPC': 'quandl_puerto_rico_gdp_per_capita',
#  'MMRCI': 'quandl_myanmar_competitiveness_index',
#  'GUYCI': 'quandl_guyana_competitiveness_index',
#  'XKXDINV': 'quandl_kosovo_changes_in_inventories',
#  'KWTTOUR': 'quandl_kuwait_tourist_arrivals',
#  'XKXCAGDP': 'quandl_kosovo_current_account_to_gdp',
#  'INDPSAV': 'quandl_india_households_savings',
#  'SURGBGT': 'quandl_suriname_government_budget',
#  'TZAWAGE': 'quandl_tanzania_monthly_average_wages_in_private_sector',
#  'CAFCA': 'quandl_central_african_republic_current_account',
#  'NCLGAGR': 'quandl_new_caledonia_gdp_annual_growth_rate',
#  'TCDCA': 'quandl_chad_current_account',
#  'TCDIMVOL': 'quandl_chad_imports',
#  'YEMGBGT': 'quandl_yemen_government_budget',
#  'PANGDG': 'quandl_panama_government_debt_to_gdp',
#  'DJIIR': 'quandl_djibouti_interest_rate',
#  'SURCAGDP': 'quandl_suriname_current_account_to_gdp',
#  'CIVGCP': 'quandl_ivory_coast_gdp_constant_prices',
#  'CIVGFCF': 'quandl_ivory_coast_gross_fixed_capital_formation',
#  'CIVGSP': 'quandl_ivory_coast_government_spending',
#  'DZAGCP': 'quandl_algeria_gdp_constant_prices',
#  'GRLG': 'quandl_greenland_gdp',
#  'JORCSP': 'quandl_jordan_consumer_spending',
#  'JORGFCF': 'quandl_jordan_gross_fixed_capital_formation',
#  'JORGSP': 'quandl_jordan_government_spending',
#  'LBNCSP': 'quandl_lebanon_consumer_spending',
#  'LBNGCP': 'quandl_lebanon_gdp_constant_prices',
#  'LBNGSP': 'quandl_lebanon_government_spending',
#  'YEMBOT': 'quandl_yemen_balance_of_trade',
#  'AFGCA': 'quandl_afghanistan_current_account',
#  'AFGCAGDP': 'quandl_afghanistan_current_account_to_gdp',
#  'FRATOUR': 'quandl_france_tourist_arrivals',
#  'LBYGDG': 'quandl_libya_government_debt_to_gdp',
#  'MNECAGDP': 'quandl_montenegro_current_account_to_gdp',
#  'URYREM': 'quandl_uruguay_remittances',
#  'YEMCAGDP': 'quandl_yemen_current_account_to_gdp',
#  'ALBDINV': 'quandl_albania_changes_in_inventories',
#  'YEMGCP': 'quandl_yemen_gdp_constant_prices',
#  'YEMGNP': 'quandl_yemen_gross_national_product',
#  'YEMGSP': 'quandl_yemen_government_spending',
#  'VENIBOR': 'quandl_venezuela_commercial_bank_loan_rate',
#  'SVNEXPX': 'quandl_slovenia_export_prices',
#  'SVNIMPX': 'quandl_slovenia_import_prices',
#  'SOMCPIC': 'quandl_somalia_inflation_rate',
#  'AFGCEMP': 'quandl_afghanistan_cement_production',
#  'AFGELPR': 'quandl_afghanistan_electricity_production',
#  'AFGMINPRO': 'quandl_afghanistan_mining_production',
#  'ISLWAGE': 'quandl_iceland_average_monthly_wage',
#  'SSDBOT': 'quandl_south_sudan_balance_of_trade',
#  'SSDEXVOL': 'quandl_south_sudan_exports',
#  'SSDG': 'quandl_south_sudan_gdp',
#  'SSDGPCP': 'quandl_south_sudan_gdp_per_capita_ppp',
#  'SSDIMVOL': 'quandl_south_sudan_imports',
#  'CODBOT': 'quandl_congo_balance_of_trade',
#  'CODEXVOL': 'quandl_congo_exports',
#  'CODIMVOL': 'quandl_congo_imports',
#  'CODIP': 'quandl_congo_industrial_production',
#  'PHLWAGE': 'quandl_philippines_wage_index',
#  'SYRGCP': 'quandl_syria_gdp_constant_prices',
#  'ISLDPINC': 'quandl_iceland_disposable_income_per_capita',
#  'PNGCAGDP': 'quandl_papua_new_guinea_current_account_to_gdp',
#  'PNGGDG': 'quandl_papua_new_guinea_government_debt_to_gdp',
#  'PSEG': 'quandl_palestine_gdp',
#  'PSEGPC': 'quandl_palestine_gdp_per_capita',
#  'ISRGBGT': 'quandl_israel_government_budget',
#  'MYSCAGDP': 'quandl_malaysia_current_account_to_gdp',
#  'TURCOP': 'quandl_turkey_construction_output',
#  'MCOGAGR': 'quandl_monaco_gdp_annual_growth_rate',
#  'CODGBGT': 'quandl_congo_government_budget',
#  'ERIBOT': 'quandl_eritrea_balance_of_trade',
#  'ERIEXVOL': 'quandl_eritrea_exports',
#  'ERIIMVOL': 'quandl_eritrea_imports',
#  'MNGGDG': 'quandl_mongolia_government_debt_to_gdp',
#  'TWNGDG': 'quandl_taiwan_government_debt_to_gdp',
#  'VNMEDBT': 'quandl_vietnam_total_external_debt',
#  'INDUNP': 'quandl_india_unemployed_persons',
#  'LIEGAGR': 'quandl_liechtenstein_gdp_annual_growth_rate',
#  'SYRGAGR': 'quandl_syria_gdp_annual_growth_rate',
#  'TLSGBGT': 'quandl_east_timor_government_budget',
#  'ARMGDG': 'quandl_armenia_government_debt_to_gdp',
#  'NAMUNR': 'quandl_namibia_unemployment_rate',
#  'BGDEMP': 'quandl_bangladesh_employed_persons',
#  'MNGGBGT': 'quandl_mongolia_government_budget',
#  'PRIGPCP': 'quandl_puerto_rico_gdp_per_capita_ppp',
#  'SURGDG': 'quandl_suriname_government_debt_to_gdp',
#  'TUNCSP': 'quandl_tunisia_consumer_spending',
#  'TUNDINV': 'quandl_tunisia_changes_in_inventories',
#  'TUNGFCF': 'quandl_tunisia_gross_fixed_capital_formation',
#  'TUNGSP': 'quandl_tunisia_government_spending',
#  'TUNTOUR': 'quandl_tunisia_tourist_arrivals',
#  'UZBCSP': 'quandl_uzbekistan_consumer_spending',
#  'UZBGSP': 'quandl_uzbekistan_government_spending',
#  'YEMFDI': 'quandl_yemen_foreign_direct_investment_inflows',
#  'YEMG': 'quandl_yemen_gdp',
#  'YEMGPC': 'quandl_yemen_gdp_per_capita',
#  'YEMGPCP': 'quandl_yemen_gdp_per_capita_ppp',
#  'ZWEGBGT': 'quandl_zimbabwe_government_budget',
#  'SYRBOT': 'quandl_syria_balance_of_trade',
#  'SYREXVOL': 'quandl_syria_exports',
#  'SYRIMVOL': 'quandl_syria_imports',
#  'HKGLC': 'quandl_hong_kong_labour_costs',
#  'MYSCU': 'quandl_malaysia_capacity_utilization',
#  'CZEIR': 'quandl_czech_republic_interest_rate',
#  'INDCRR': 'quandl_india_cash_reserve_ratio',
#  'MEXIR': 'quandl_mexico_interest_rate',
#  'UGAIR': 'quandl_uganda_interest_rate',
#  'ROUIR': 'quandl_romania_interest_rate',
#  'ZMBIR': 'quandl_zambia_interest_rate',
#  'SRBIR': 'quandl_serbia_interest_rate',
#  'GBRIR': 'quandl_united_kingdom_interest_rate',
#  'PHLIR': 'quandl_philippines_interest_rate',
#  'INDIR': 'quandl_india_interest_rate',
#  'RUSCBBS': 'quandl_russia_central_bank_balance_sheet',
#  'RWAIR': 'quandl_rwanda_interest_rate',
#  'PERIR': 'quandl_peru_interest_rate',
#  'TURIBOR': 'quandl_turkey_three_month_interbank_rate',
#  'HRVIBOR': 'quandl_croatia_overnight_interbank_rate',
#  'CHLIBOR': 'quandl_chile_three_month_interbank_rate',
#  'ECUIBOR': 'quandl_ecuador_interbank_weighted_average_rate',
#  'SGPIBOR': 'quandl_singapore_three_month_interbank_rate',
#  'HKGIBOR': 'quandl_hong_kong_three_month_interbank_rate',
#  'USAACOSC': 'quandl_united_states_api_crude_oil_stock_change',
#  'BGRIBOR': 'quandl_bulgaria_three_month_interbank_rate',
#  'KORIBOR': 'quandl_south_korea_three_month_interbank_rate',
#  'ESPIBOR': 'quandl_spain_three_month_interbank_rate',
#  'FINIBOR': 'quandl_finland_three_month_interbank_rate',
#  'EURIBOR': 'quandl_euro_area_euro_libor_three_month_rate',
#  'DNKIBOR': 'quandl_denmark_three_month_interbank_rate',
#  'CANIBOR': 'quandl_canada_three_month_interbank_rate_(cidor)',
#  'IDNIBOR': 'quandl_indonesia_three_month_interbank_rate',
#  'UKRIBOR': 'quandl_ukraine_three_months_interbank_rate',
#  'ROUIBOR': 'quandl_romania_three_month_interbank_rate',
#  'ZAFIBOR': 'quandl_south_africa_three_month_interbank_rate',
#  'JPNIBOR': 'quandl_japan_japanese_yen_libor_three_month_rate',
#  'PHLIBOR': 'quandl_philippines_up_to_one_day_interbank_rate',
#  'ISRIBOR': 'quandl_israel_three_month_interbank_rate',
#  'LKAIBOR': 'quandl_sri_lanka_three_month_interbank_rate',
#  'RUSIR': 'quandl_russia_interest_rate',
#  'HUNIBOR': 'quandl_hungary_three_month_interbank_rate',
#  'POLIBOR': 'quandl_poland_three_month_interbank_rate',
#  'MYSIBOR': 'quandl_malaysia_three_month_interbank_rate',
#  'CHNIBOR': 'quandl_china_three_month_interbank_rate',
#  'SWEIBOR': 'quandl_sweden_three_month_interbank_rate',
#  'TWNIBOR': 'quandl_taiwan_three_month_interbank_rate',
#  'ISLIBOR': 'quandl_iceland_three_month_interbank_rate',
#  'CZEIBOR': 'quandl_czech_republic_three_month_interbank_rate',
#  'CHEIBOR': 'quandl_switzerland_swiss_franc_libor_three_month_rate',
#  'GBRIBOR': 'quandl_united_kingdom_british_pound_libor_three_month_rate',
#  'NORIBOR': 'quandl_norway_three_month_interbank_rate',
#  'USACOR': 'quandl_united_states_baker_hughes_crude_oil_rigs',
#  'LVAIBOR': 'quandl_latvia_three_month_interbank_rate',
#  'JPNGYLD': 'quandl_japan_government_bond_10y',
#  'USARDBK': 'quandl_united_states_redbook_index',
#  'BGDPPI': 'quandl_bangladesh_producer_prices',
#  'CYMGPC': 'quandl_cayman_islands_gdp_per_capita',
#  'JORDINV': 'quandl_jordan_changes_in_inventories',
#  'USATOUR': 'quandl_united_states_tourist_arrivals',
#  'BDICPI': 'quandl_burundi_consumer_price_index_cpi',
#  'BENCPI': 'quandl_benin_consumer_price_index_(cpi)',
#  'MMRTOUR': 'quandl_myanmar_tourist_arrivals',
#  'MKDCCONF': 'quandl_macedonia_consumer_credit',
#  'SYRCPIC': 'quandl_syria_inflation_rate',
#  'COGCPIC': 'quandl_republic_of_the_congo_inflation_rate',
#  'SYRCPI': 'quandl_syria_consumer_price_index_(cpi)',
#  'TJKBOT': 'quandl_tajikistan_balance_of_trade',
#  'TJKEXVOL': 'quandl_tajikistan_exports',
#  'TJKIMVOL': 'quandl_tajikistan_imports',
#  'TJKIP': 'quandl_tajikistan_industrial_production',
#  'COLMKT': 'quandl_colombia_stock_market_(igbc)',
#  'PAKMKT': 'quandl_pakistan_stock_market_(kse100)',
#  'ISRGYLD': 'quandl_israel_government_bond_10y',
#  'KENGYLD': 'quandl_kenya_government_bond_10y',
#  'DNKGYLD': 'quandl_denmark_government_bond_10y',
#  'MEXGYLD': 'quandl_mexico_government_bond_10y',
#  'BHRMKT': 'quandl_bahrain_stock_market_(bahrain_all_share)',
#  'VNMGYLD': 'quandl_vietnam_government_bond_10y',
#  'NGAGYLD': 'quandl_nigeria_government_bond_10y',
#  'SVNGYLD': 'quandl_slovenia_government_bond_10y',
#  'TURGYLD': 'quandl_turkey_government_bond_10y',
#  'SWEMKT': 'quandl_sweden_stock_market_(omx_30)',
#  'RUSGYLD': 'quandl_russia_government_bond_10y',
#  'VENMKT': 'quandl_venezuela_stock_market_(ibvc)',
#  'OMNMKT': 'quandl_oman_stock_market_(msm_30)',
#  'CHLMKT': 'quandl_chile_stock_market_(igpa)',
#  'GRCMKT': 'quandl_greece_stock_market_(ase)',
#  'DEUGYLD': 'quandl_germany_government_bond_10y',
#  'GBRGYLD': 'quandl_united_kingdom_government_bond_10y',
#  'GRCGYLD': 'quandl_greece_government_bond_10y',
#  'ESPMKT': 'quandl_spain_stock_market_(ibex_35)',
#  'HKGGYLD': 'quandl_hong_kong_government_bond_10y',
#  'CZEGYLD': 'quandl_czech_republic_government_bond_10y',
#  'DNKMKT': 'quandl_denmark_stock_market_omx_copenhagen_index_kfx',
#  'THAMKT': 'quandl_thailand_stock_market_(set50)',
#  'BTNCUR': 'quandl_bhutan_indian_rupee\xa0',
#  'PAKGYLD': 'quandl_pakistan_government_bond_10y',
#  'SWEGYLD': 'quandl_sweden_government_bond_10y',
#  'PHLGYLD': 'quandl_philippines_government_bond_10y',
#  'ESPGYLD': 'quandl_spain_government_bond_10y',
#  'HRVGYLD': 'quandl_croatia_government_bond_10y',
#  'SAUMKT': 'quandl_saudi_arabia_stock_market_(tasi)',
#  'BRAGYLD': 'quandl_brazil_government_bond_10y',
#  'ITAGYLD': 'quandl_italy_government_bond_10y',
#  'SVKMKT': 'quandl_slovakia_stock_market_(sax)',
#  'PANMKT': 'quandl_panama_stock_market_(bvpsi)\xa0',
#  'LUXMKT': 'quandl_luxembourg_stock_market_(luxx)',
#  'CHEMKT': 'quandl_switzerland_stock_market_(smi)',
#  'ISRMKT': 'quandl_israel_stock_market_(ta_100)',
#  'ARGCUR': 'quandl_argentina_argentinean_peso',
#  'CANGYLD': 'quandl_canada_government_bond_10y',
#  'MYSGYLD': 'quandl_malaysia_government_bond_10y',
#  'CHEGYLD': 'quandl_switzerland_government_bond_10y',
#  'SVNMKT': 'quandl_slovenia_stock_market_(sbitop)\xa0',
#  'HUNGYLD': 'quandl_hungary_government_bond_10y',
#  'IRLGYLD': 'quandl_ireland_government_bond_10y',
#  'CYPMKT': 'quandl_cyprus_stock_market_(cyprus_general)',
#  'LTUGYLD': 'quandl_lithuania_government_bond_10y',
#  'EURMKT': 'quandl_euro_area_euro_stoxx_50_stock_market_index',
#  'GHAMKT': 'quandl_ghana_stock_market_composite_gse_ci',
#  'FRAGYLD': 'quandl_france_government_bond_10y',
#  'ZAFGYLD': 'quandl_south_africa_government_bond_10y',
#  'HRVMKT': 'quandl_croatia_stock_market_(crobex)\xa0',
#  'BGDMKT': 'quandl_bangladesh_stock_market_(dse_broad)',
#  'BELMKT': 'quandl_belgium_stock_market_(bel20)',
#  'TURMKT': 'quandl_turkey_stock_market_(xu100)',
#  'CHNGYLD': 'quandl_china_government_bond_10y',
#  'NLDMKT': 'quandl_netherlands_stock_market_(aex)',
#  'NORMKT': 'quandl_norway_stock_market_(oseax)',
#  'IRLMKT': 'quandl_ireland_stock_market_(iseq)',
#  'QATMKT': 'quandl_qatar_stock_market_(qe_general)',
#  'IDNGYLD': 'quandl_indonesia_government_bond_10y',
#  'BRAMKT': 'quandl_brazil_stock_market_(bovespa)',
#  'CZEMKT': 'quandl_czech_republic_stock_market_(se_px)',
#  'AUTGYLD': 'quandl_austria_government_bond_10y',
#  'LVAGYLD': 'quandl_latvia_government_bond_10y',
#  'TUNMKT': 'quandl_tunisia_stock_market_(tunindex)\xa0',
#  'CANMKT': 'quandl_canada_s&p/tsx_toronto_stock_market_index',
#  'MOZIR': 'quandl_mozambique_interest_rate',
#  'THAGYLD': 'quandl_thailand_government_bond_10y',
#  'LKAMKT': 'quandl_sri_lanka_stock_market_(cse_all_share)',
#  'COLGYLD': 'quandl_colombia_government_bond_10y',
#  'ROUGYLD': 'quandl_romania_government_bond_10y',
#  'TWNMKT': 'quandl_taiwan_stock_market_(twse)',
#  'BWAMKT': 'quandl_botswana_stock_market_(bsi_dci)',
#  'INDGYLD': 'quandl_india_government_bond_10y',
#  'UKRMKT': 'quandl_ukraine_stock_market_(pfts)',
#  'PRTGYLD': 'quandl_portugal_government_bond_10y',
#  'ECUMKT': 'quandl_ecuador_general_index',
#  'BGRGYLD': 'quandl_bulgaria_government_bond_10y',
#  'TWNGYLD': 'quandl_taiwan_government_bond_10y',
#  'MEXMKT': 'quandl_mexico_ipc_stock_market',
#  'VENGYLD': 'quandl_venezuela_government_bond_10y',
#  'NORGYLD': 'quandl_norway_government_bond_10y',
#  'NLDGYLD': 'quandl_netherlands_government_bond_10y',
#  'ESTMKT': 'quandl_estonia_stock_market_(omx_tallin)',
#  'JORMKT': 'quandl_jordan_stock_market_(ase_general)',
#  'LVAMKT': 'quandl_latvia_stock_market_(omx_riga)',
#  'SVKGYLD': 'quandl_slovakia_government_bond_10y',
#  'ISLMKT': 'quandl_iceland_stock_market_(se_icex)',
#  'PRTMKT': 'quandl_portugal_stock_market_(psi20)',
#  'SRBMKT': 'quandl_serbia_stock_market_(belex15)\xa0',
#  'DEUMKT': 'quandl_germany_stock_market_(dax)\xa0',
#  'PHLMKT': 'quandl_philippines_stock_market_(psei)\xa0',
#  'MUSMKT': 'quandl_mauritius_stock_market_(semdex)',
#  'PERGYLD': 'quandl_peru_government_nine_year_bond_yield',
#  'BRACUR': 'quandl_brazil_brazilian_real',
#  'JAMMKT': 'quandl_jamaica_stock_market_(jamaica_se)',
#  'AUTMKT': 'quandl_austria_stock_market_(atx)',
#  'FINMKT': 'quandl_finland_stock_market_(hex25)',
#  'USAMKT': 'quandl_united_states_dow_jones_industrial_average',
#  'IDNMKT': 'quandl_indonesia_stock_market_(jci)',
#  'FINGYLD': 'quandl_finland_government_bond_10y',
#  'KENMKT': 'quandl_kenya_stock_market_(nse20)',
#  'LBNMKT': 'quandl_lebanon_stock_market_blom',
#  'MARMKT': 'quandl_morocco_stock_market_masi',
#  'NGAMKT': 'quandl_nigeria_stock_market_(nse_30)\xa0',
#  'POLMKT': 'quandl_poland_warsaw_stock_exchange_wig_index',
#  'VNMMKT': 'quandl_vietnam_ho_chi_minh_stock_index',
#  'POLGYLD': 'quandl_poland_government_bond_10y',
#  'AREMKT': 'quandl_united_arab_emirates_stock_market_(adx_general)\xa0',
#  'KWTMKT': 'quandl_kuwait_stock_exchange_index',
#  'BGDCUR': 'quandl_bangladesh_bangladeshi_taka',
#  'ITAMKT': 'quandl_italy_stock_market_(ftse_mib)',
#  'BGRMKT': 'quandl_bulgaria_stock_market_(sofix)',
#  'ZAFMKT': 'quandl_south_africa_stock_market',
#  'EGYMKT': 'quandl_egypt_stock_market_(egx30)',
#  'HUNMKT': 'quandl_hungary_stock_market_(bux)',
#  'PERMKT': 'quandl_peru_s&p/bvl_general_index_tr_(pen)',
#  'ROUMKT': 'quandl_romania_stock_market_(bet)',
#  'ISLGYLD': 'quandl_iceland_government_bond_10y',
#  'FRAMKT': 'quandl_france_cac_40_stock_market_index',
#  'BHRCUR': 'quandl_bahrain_bahraini_dinar',
#  'DZACUR': 'quandl_algeria_algerian_dinar',
#  'BENCUR': 'quandl_benin_currency',
#  'BFACUR': 'quandl_burkina_faso_currency',
#  'CAFCUR': 'quandl_central_african_republic_currency\xa0',
#  'CMRCUR': 'quandl_cameroon_central_african_franc_usdxaf',
#  'TCDCUR': 'quandl_chad_currency',
#  'CHLCUR': 'quandl_chile_chilean_peso',
#  'CHLGYLD': 'quandl_chile_government_bond_10y',
#  'KORGYLD': 'quandl_south_korea_government_bond_10y',
#  'INDMKT': 'quandl_india_sensex_stock_market_index',
#  'MYSMKT': 'quandl_malaysia_stock_market_(ftse_klci)',
#  'BLRCUR': 'quandl_belarus_belarusian_rubble',
#  'AUSCUR': 'quandl_australia_australian_dollar',
#  'BRNCUR': 'quandl_brunei_dollar',
#  'ALBCUR': 'quandl_albania_albanian_lek',
#  'BHSCUR': 'quandl_bahamas_bahamian_dollar',
#  'SGPMKT': 'quandl_singapore_stock_market_(sti)',
#  'CANCUR': 'quandl_canada_canadian_dollar',
#  'AFGCUR': 'quandl_afghanistan_afghan_afghani',
#  'BWACUR': 'quandl_botswana_pula',
#  'HKGMKT': 'quandl_hong_kong_stock_market_(hsi)',
#  'JPNMKT': 'quandl_japan_nikkei_225_stock_market_index',
#  'KORMKT': 'quandl_south_korea_stock_market_(kospi)',
#  'ARMCUR': 'quandl_armenia_armenian_dram',
#  'KHMCUR': 'quandl_cambodia_cambodian_riel\xa0',
#  'CYMCUR': 'quandl_cayman_islands_dollar',
#  'BDICUR': 'quandl_burundi_burundian_franc',
#  'BIHCUR': 'quandl_bosnia_and_herzegovina_bosnian_mark\xa0',
#  'RUSMKT': 'quandl_russia_stock_market_(micex)\xa0',
#  'NZLMKT': 'quandl_new_zealand_stock_market_(nzx_50)',
#  'GBRMKT': 'quandl_united_kingdom_uk_ftse_100_stock_market_index',
#  'AGOCUR': 'quandl_angola_angolan_kwanza',
#  'SGPGYLD': 'quandl_singapore_government_bond_10y',
#  'NZLGYLD': 'quandl_new_zealand_government_bond_10y',
#  'BELGYLD': 'quandl_belgium_government_bond_10y',
#  'AZECUR': 'quandl_azerbaijan_azerbaijani_manat',
#  'BGRCUR': 'quandl_bulgaria_bulgarian_lev',
#  'QATGYLD': 'quandl_qatar_government_bond_10y',
#  'AUSGYLD': 'quandl_australia_government_bond_10y',
#  'CPVCUR': 'quandl_cape_verde_escudo',
#  'CHNMKT': 'quandl_china_shanghai_composite_stock_market_index',
#  'AUTCUR': 'quandl_austria_euro_exchange_rate_eur/usd_austria',
#  'BELCUR': 'quandl_belgium_euro_exchange_rate_eur/usd_belgium',
#  'AUSMKT': 'quandl_australia_s&p/asx_200_stock_market_index',
#  'USAGYLD': 'quandl_united_states_government_bond_10y',
#  'COMFINF': 'quandl_comoros_food_inflation',
#  'YEMCCPI': 'quandl_yemen_core_consumer_prices',
#  'YEMCPIC': 'quandl_yemen_inflation_rate',
#  'SWEIR': 'quandl_sweden_interest_rate',
#  'CYPM2': 'quandl_cyprus_money_supply_m2',
#  'STPCPI': 'quandl_sao_tome_and_principe_sao_tome_and_principe_consumer_price_index_cpi',
#  'VENEMP': 'quandl_venezuela_employed_persons',
#  'VENUNP': 'quandl_venezuela_unemployed_persons',
#  'VENUNR': 'quandl_venezuela_unemployment_rate',
#  'TZAGAGR': 'quandl_tanzania_gdp_annual_growth_rate',
#  'LUXREM': 'quandl_luxembourg_remittances',
#  'FINREM': 'quandl_finland_remittances',
#  'MKDGGR': 'quandl_macedonia_gdp_growth_rate',
#  'TZAGGR': 'quandl_tanzania_gdp_growth_rate',
#  'POLIR': 'quandl_poland_interest_rate',
#  'ALBDIR': 'quandl_albania_overnight_deposit_interest_rate',
#  'ALBLENDR': 'quandl_albania_overnight_lending_rate',
#  'DEUCNCN': 'quandl_germany_consumer_confidence',
#  'USAOPT': 'quandl_united_states_ibd/tipp_economic_optimism_index',
#  'RUSMPMI': 'quandl_russia_manufacturing_pmi',
#  'NORIR': 'quandl_norway_interest_rate',
#  'ARGMINWG': 'quandl_argentina_minimum_monthly_wage',
#  'PRKINFR': 'quandl_north_korea_inflation_rate',
#  'IRLNO': 'quandl_ireland_new_orders',
#  'NZLM2': 'quandl_new_zealand_money_supply_m2',
#  'NZLCCONF': 'quandl_new_zealand_consumer_credit',
#  'INDBCONF': 'quandl_india_business_confidence',
#  'EGYFDI': 'quandl_egypt_foreign_direct_investment',
#  'PHLHOUS': 'quandl_philippines_housing_sales',
#  'SDNCA': 'quandl_sudan_current_account',
#  'MDACA': 'quandl_moldova_current_account',
#  'MDAFDI': 'quandl_moldova_foreign_direct_investment_net_inflows',
#  'TTOBOT': 'quandl_trinidad_and_tobago_balance_of_trade',
#  'TTOEXVOL': 'quandl_trinidad_and_tobago_exports',
#  'TTOIMVOL': 'quandl_trinidad_and_tobago_imports',
#  'IRNCSP': 'quandl_iran_consumer_spending',
#  'IRNGCP': 'quandl_iran_gdp_constant_prices',
#  'IRNGFCF': 'quandl_iran_gross_fixed_capital_formation',
#  ...}

# %%
def prepare_dataset(ds_code, data):
    """
    Clean up key values and make a dataframe out of it for storage.

    :param ds_code: QUANDL code of the dataset.
    :param data: dictionary with data.
    :return df: final dataframe to be stored
    """
    new_data = []
    for k,v in data.items():
        tmp_dict = {}
        tmp_dict["name"] = ds_code
        tmp_dict["date_time"] = k.to_pydatetime().strftime("%Y-%m-%d")
        tmp_dict["year"] = k.to_pydatetime().strftime("%Y")
        tmp_dict["value"] = v
        new_data.append(tmp_dict)
    return pd.DataFrame(new_data)

list_dfs = []
for k,d in macro_econo_df.items():
    code = k.replace("SGE/","").replace(" - Value","")
    df =prepare_dataset(code,d)
    df.to_csv(f"../data/output/quandl/{code}.csv", index=False)
# Out:
#      name   date_time  year     value
# 0  ANDGPC  2009-12-31  2009  41860.24
# 1  ANDGPC  2010-12-31  2010  39627.66
# 2  ANDGPC  2011-12-31  2011  38038.88
# 3  ANDGPC  2012-12-31  2012  37967.80
# 4  ANDGPC  2013-12-31  2013  38715.36
